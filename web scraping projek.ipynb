# %%
#masukan dalam 1 file bahan yang sudah di install tadi
#seperti selenium, BeautifulSoup kemudian import
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
#chromedriver file yang sudah di download dan perintah ini 
#akan membuka chrome baru secara otomatis
driver = webdriver.Chrome("chromedriver")

# %%
#ini membuat variabel dengan data array kosong
#yang nantinya akan di gunakan untuk excel
product=[]
prices=[]
image=[]
#ini link url web yang akan digunakan untuk scaping nya
driver.get("https://www.ikea.co.id/in/search/?q=meja")

# %%
#content yaitu variabel
#driver.page_source ini koneksi link url web scraping na 
#variabel soup isinya variabel data content dan diformat kedalam
#bentuk BeautifulSoup agar dapat diakses isi konten web nya
content = driver.page_source
soup = BeautifulSoup(content)
soup
# Out:
# <html class="" lang="id"><head><script async="" src="//acdn.adnxs.com/dmp/up/pixie.js"></script>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Hasil Pencarian untuk meja | IKEA Indonesia</title>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no, shrink-to-fit=no" name="viewport"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <style>@font-face{font-family:'NotoIKEA';src:url(/webroot/fonts/NotoIKEALatin/NotoIKEALatin-Regular.woff) format("woff");font-weight:normal;font-style:normal}@font-face{font-family:'NotoIKEA';src:url(/webroot/fonts/NotoIKEALatin/NotoIKEALatin-Bold.woff) format("woff");font-weight:bold;font-style:normal}@font-face{font-family:'NotoIKEA';src:url(/webroot/fonts/NotoIKEALatin/NotoIKEALatin-Italic.woff) format("woff");font-weight:normal;font-style:italic}@font-face{font-family:'NotoIKEA';src:url(/webroot/fonts/NotoIKEALatin/NotoIKEALatin-BoldItalic.woff) format("woff");font-weight:bold;font-style:italic}@font-face{font-family:'FontAwesome';src:url(/webroot/fonts/font-awesome/fontawesome-webfont.eot?v=4.7.0);src:url(/webroot/fonts/font-awesome/fontawesome-webfont.eot?#iefix&v=4.7.0) format("embedded-opentype") , url(/webroot/fonts/font-awesome/fontawesome-webfont.woff2?v=4.7.0) format("woff2") , url(/webroot/fonts/font-awesome/fontawesome-webfont.woff?v=4.7.0) format("woff") , url(/webroot/fonts/font-awesome/fontawesome-webfont.ttf?v=4.7.0) format("truetype") , url(/webroot/fonts/font-awesome/fontawesome-webfont.svg?v=4.7.0#fontawesomeregular) format("svg");font-weight:normal;font-style:normal}:root{--blue:#039;--indigo:#6610f2;--purple:#6f42c1;--pink:#e83e8c;--red:#c00;--orange:#f60;--yellow:#ffba00;--green:#090;--teal:#20c997;--cyan:#17a2b8;--white:#fff;--gray:#6c757d;--gray-dark:#343a40;--gray-light:#ced4da;--blue-ikea:#039;--yellow-ikea:#fc0;--family-brand:#c00;--business-brand:#3399fd;--badge-new:#f07f3b;--badge-nlp:#e42312;--sales:#c20000;--blue-link:#427ab3;--orange-link:#f60;--primary:#039;--secondary:#6c757d;--success:#090;--info:#17a2b8;--warning:#f60;--danger:#c00;--light:#f8f9fa;--dark:#343a40;--blue:#039;--indigo:#6610f2;--purple:#6f42c1;--pink:#e83e8c;--red:#c00;--orange:#f60;--yellow:#ffba00;--green:#090;--teal:#20c997;--cyan:#17a2b8;--white:#fff;--gray-light:#ced4da;--gray-medium:#adb5bd;--gray:#6c757d;--gray-dark:#343a40;--blue-ikea:#039;--yellow-ikea:#fc0;--family-brand:#c00;--business-brand:#3399fd;--badge-new:#f07f3b;--badge-nlp:#e42312;--blue-link:#427ab3;--orange-link:#f60;--transparent:rgba(0,0,0,0);--breakpoint-xs:0;--breakpoint-sm:576px;--breakpoint-md:768px;--breakpoint-lg:992px;--breakpoint-xl:1200px;--font-family-sans-serif:"NotoIKEA" , "Verdana" , -apple-system , BlinkMacSystemFont , "Segoe UI" , Roboto , "Helvetica Neue" , Arial , sans-serif;--font-family-monospace:SFMono-Regular , Menlo , Monaco , Consolas , "Liberation Mono" , "Courier New" , monospace}*,*::before,*::after{-webkit-box-sizing:border-box;box-sizing:border-box}html{font-family:sans-serif;line-height:1.15;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%;-ms-overflow-style:scrollbar;-webkit-tap-highlight-color:rgba(0,0,0,0)}@-ms-viewport { width: device-width; }footer,header,nav,section{display:block}body{margin:0;font-family:"NotoIKEA","Verdana",-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,sans-serif;font-size:1rem;font-weight:400;line-height:1.5;color:#212529;text-align:left;background-color:#fff}[tabindex="-1"]:focus{outline:0!important}hr{-webkit-box-sizing:content-box;box-sizing:content-box;height:0;overflow:visible}h1,h2,h4,h5,h6{margin-top:0;margin-bottom:.5rem}p{margin-top:0;margin-bottom:1rem}ol,ul{margin-top:0;margin-bottom:1rem}ul ul{margin-bottom:0}strong{font-weight:bolder}a{color:#427ab3;text-decoration:none;background-color:transparent;-webkit-text-decoration-skip:objects}a:hover{color:#2d547b;text-decoration:underline}a:not([href]):not([tabindex]) {color:inherit;text-decoration:none}a:not([href]):not([tabindex]):hover, a:not([href]):not([tabindex]):focus {color:inherit;text-decoration:none}a:not([href]):not([tabindex]):focus {outline:0}img{vertical-align:middle;border-style:none;margin:auto}svg:not(:root) {overflow:hidden}label{display:inline-block;margin-bottom:.5rem}button{border-radius:0}button:focus{outline:1px dotted;outline:5px auto -webkit-focus-ring-color}input,button,textarea{mar ...
#   to { background-position: 0 0; } }@keyframes progress-bar-stripes { from { background-position: 1rem 0; }
#   to { background-position: 0 0; } }.close{float:right;font-size:1.5rem;font-weight:700;line-height:1;color:#000;text-shadow:0 1px 0 #fff;opacity:.5}.close:hover,.close:focus{color:#000;text-decoration:none;opacity:.75}.close:not(:disabled):not(.disabled) {cursor:pointer}button.close{padding:0;background-color:transparent;border:0;-webkit-appearance:none}.modal{position:fixed;top:0;right:0;bottom:0;left:0;z-index:1050;display:none;overflow:hidden;outline:0}.modal-dialog{position:relative;width:auto;margin:.5rem;pointer-events:none}.modal.fade .modal-dialog{-webkit-transition:-webkit-transform .3s ease-out;transition:-webkit-transform .3s ease-out;-o-transition:transform .3s ease-out;transition:transform .3s ease-out;transition:transform .3s ease-out , -webkit-transform .3s ease-out;-webkit-transform:translate(0,-25%);-ms-transform:translate(0,-25%);transform:translate(0,-25%)}.modal-content{position:relative;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:vertical;-webkit-box-direction:normal;-ms-flex-direction:column;flex-direction:column;width:100%;pointer-events:auto;background-color:#fff;background-clip:padding-box;border:1px solid rgba(0,0,0,.2);border-radius:.3rem;outline:0}.modal-header{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:start;-ms-flex-align:start;align-items:flex-start;-webkit-box-pack:justify;-ms-flex-pack:justify;justify-content:space-between;padding:1rem;border-bottom:1px solid #e9ecef;border-top-left-radius:.3rem;border-top-right-radius:.3rem}.modal-header .close{padding:1rem;margin:-1rem -1rem -1rem auto}.modal-body{position:relative;-webkit-box-flex:1;-ms-flex:1 1 auto;flex:1 1 auto;padding:1rem}.modal-footer{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:end;-ms-flex-pack:end;justify-content:flex-end;padding:1rem;border-top:1px solid #e9ecef}.modal-footer > :not(:first-child) {margin-left:.25rem}.modal-footer > :not(:last-child) {margin-right:.25rem}@media (min-width:576px){.modal-dialog{max-width:500px;margin:1.75rem auto}}@media (min-width:992px){.modal-lg{max-width:800px}}@supports ((-webkit-transform-style: preserve-3d) or (transform-style: preserve-3d)) { .carousel-item-next.carousel-item-left, .carousel-item-prev.carousel-item-right { -webkit-transform: translate3d(0, 0, 0); transform: translate3d(0, 0, 0); } }@supports ((-webkit-transform-style: preserve-3d) or (transform-style: preserve-3d)) { .carousel-item-next, .active.carousel-item-right { -webkit-transform: translate3d(100%, 0, 0); transform: translate3d(100%, 0, 0); } }@supports ((-webkit-transform-style: preserve-3d) or (transform-style: preserve-3d)) { .carousel-item-prev, .active.carousel-item-left { -webkit-transform: translate3d(-100%, 0, 0); transform: translate3d(-100%, 0, 0); } }.bg-white{background-color:#fff!important}.bg-white{background-color:#fff!important}.border-bottom{border-bottom:1px solid #dee2e6!important}.d-none{display:none!important}.d-inline{display:inline!important}.d-inline-block{display:inline-block!important}.d-block{display:block!important}.d-flex{display:-webkit-box!important;display:-ms-flexbox!important;display:flex!important}@media (min-width:576px){.d-sm-none{display:none!important}.d-sm-inline{display:inline!important}.d-sm-block{display:block!important}}@media (min-width:768px){.d-md-none{display:none!important}}@media (min-width:992px){.d-lg-none{display:none!important}.d-lg-inline{display:inline!important}.d-lg-block{display:block!important}.d-lg-flex{display:-webkit-box!important;display:-ms-flexbox!important;display:flex!important}}.flex-column{-webkit-box-orient:vertical!important;-webkit-box-direction:normal!important;-ms-flex-direction:column!important;flex-direction:column!important}.flex-wrap{-ms-flex-wrap:wrap!important;flex-wrap:wrap!important}.justify-content-end{-webkit-box-pack:end!important;-ms-flex-pack:end!important;justify-content:flex-end!important ...
#     transform: rotate(0deg); }
#   100% { -webkit-transform: rotate(359deg);
#     transform: rotate(359deg); } }@keyframes fa-spin { 0% { -webkit-transform: rotate(0deg);
#     transform: rotate(0deg); }
#   100% { -webkit-transform: rotate(359deg);
#     transform: rotate(359deg); } }:root .fa-rotate-90,:root .fa-rotate-180,:root .fa-rotate-270,:root .fa-flip-horizontal,:root .fa-flip-vertical{-webkit-filter:none;filter:none}.fa-angle-left:before{content:""}.fa-angle-right:before{content:""}.fa-circle-o-notch:before{content:""}.sr-only{position:absolute;width:1px;height:1px;padding:0;margin:-1px;overflow:hidden;clip:rect(0,0,0,0);border:0}</style> <style>@font-face{font-family:'Font Awesome 5 Brands';font-style:normal;font-weight:normal;src:url(/webroot/fonts/fontawesome-5.1.1/fa-brands-400.eot);src:url(/webroot/fonts/fontawesome-5.1.1/fa-brands-400.eot?#iefix) format("embedded-opentype") , url(/webroot/fonts/fontawesome-5.1.1/fa-brands-400.woff2) format("woff2") , url(/webroot/fonts/fontawesome-5.1.1/fa-brands-400.woff) format("woff") , url(/webroot/fonts/fontawesome-5.1.1/fa-brands-400.ttf) format("truetype") , url(/webroot/fonts/fontawesome-5.1.1/fa-brands-400.svg#fontawesome) format("svg")}@font-face{font-family:'Font Awesome 5 Free';font-style:normal;font-weight:400;src:url(/webroot/fonts/fontawesome-5.1.1/fa-regular-400.eot);src:url(/webroot/fonts/fontawesome-5.1.1/fa-regular-400.eot?#iefix) format("embedded-opentype") , url(/webroot/fonts/fontawesome-5.1.1/fa-regular-400.woff2) format("woff2") , url(/webroot/fonts/fontawesome-5.1.1/fa-regular-400.woff) format("woff") , url(/webroot/fonts/fontawesome-5.1.1/fa-regular-400.ttf) format("truetype") , url(/webroot/fonts/fontawesome-5.1.1/fa-regular-400.svg#fontawesome) format("svg")}@font-face{font-family:'Font Awesome 5 Free';font-style:normal;font-weight:900;src:url(/webroot/fonts/fontawesome-5.1.1/fa-solid-900.eot);src:url(/webroot/fonts/fontawesome-5.1.1/fa-solid-900.eot?#iefix) format("embedded-opentype") , url(/webroot/fonts/fontawesome-5.1.1/fa-solid-900.woff2) format("woff2") , url(/webroot/fonts/fontawesome-5.1.1/fa-solid-900.woff) format("woff") , url(/webroot/fonts/fontawesome-5.1.1/fa-solid-900.ttf) format("truetype") , url(/webroot/fonts/fontawesome-5.1.1/fa-solid-900.svg#fontawesome) format("svg")}@font-face{font-family:"ikea-pictograms";src:url(/webroot/fonts/ikea-pictograms/ikea-pictograms.eot);src:url(/webroot/fonts/ikea-pictograms/ikea-pictograms.eot?#iefix) format("embedded-opentype") , url(/webroot/fonts/ikea-pictograms/ikea-pictograms.woff) format("woff") , url(/webroot/fonts/ikea-pictograms/ikea-pictograms.ttf) format("truetype") , url(/webroot/fonts/ikea-pictograms/ikea-pictograms.svg#ikea-pictograms) format("svg");font-weight:normal;font-style:normal}.fa{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;display:inline-block;font-style:normal;font-variant:normal;text-rendering:auto;line-height:1}.fa-3x{font-size:3em}.fa-fw{text-align:center;width:1.25em}.fa-spin{-webkit-animation:fa-spin 2s infinite linear;animation:fa-spin 2s infinite linear}@-webkit-keyframes fa-spin {
#   0% {
#     -webkit-transform: rotate(0deg);
#             transform: rotate(0deg); }
#   100% {
#     -webkit-transform: rotate(360deg);
#             transform: rotate(360deg); } }@keyframes fa-spin {
#   0% {
#     -webkit-transform: rotate(0deg);
#             transform: rotate(0deg); }
#   100% {
#     -webkit-transform: rotate(360deg);
#             transform: rotate(360deg); } }:root .fa-rotate-90,:root .fa-rotate-180,:root .fa-rotate-270,:root .fa-flip-horizontal,:root .fa-flip-vertical{-webkit-filter:none;filter:none}.fa-angle-left:before{content:"\f104"}.fa-angle-right:before{content:"\f105"}.sr-only{border:0;clip:rect(0,0,0,0);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px}.fa{font-family:'Font Awesome 5 Free';font-weight:900}@charset "UTF-8";[class*=" picto-"]:before{font-family:"ikea-pictograms"!important;font-style:normal!important;font-weight:normal!important;font-variant:normal!important;text-transform:none!important;speak:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;color:#427ab3;font-size:3rem}.picto-return-policy:before{content:""}.picto-where-are-we:before{content:""}</style> <style>@font-face{font-family:"ikea-icons";src:url(/webroot/fonts/ikea-icons/ikea-icons.eot?v=1q67);src:url(/webroot/fonts/ikea-icons/ikea-icons.eot?#iefix&v=1q67) format("embedded-opentype") , url(/webroot/fonts/ikea-icons/ikea-icons.woff?v=1q67) format("woff") , url(/webroot/fonts/ikea-icons/ikea-icons.ttf?v=1q67) format("truetype") , url(/webroot/fonts/ikea-icons/ikea-icons.svg#ikea-icons?v=1q67) format("svg");font-weight:normal;font-style:normal}[class^="icon-"]:before,[class*=" icon-"]:before{font-family:"ikea-icons"!important;font-style:normal!important;font-weight:normal!important;font-variant:normal!important;text-transform:none!important;speak:none;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.icon-chevron-down:before{content:""}.icon-chevron-right:before{content:""}.icon-quickview:before{content:""}.icon-filter:before{content:""}.icon-fav:before{content:""}.quickLook:hover, .quickLook:not(:disabled):not(.disabled):active {color:#343a40;background:#ced4da;border-color:#ced4da}.quickLook{width:100%;background:transparent;border:1px solid #ced4da;padding-top:.45rem;padding-bottom:.45rem;padding-left:1rem;padding-right:1rem;color:#6c757d}@media (min-width:576px){.quickLook{padding-left:3rem;padding-right:3rem}}.quickLook:not(:disabled):not(.disabled):active {color:#222}.addToProduct span:not(.icon), .unselectToProduct span:not(.icon) {font-weight:600}.modalConfirmationButton{color:#000;background:transparent;border:1px solid #000;margin:0;padding:8px 20px;font-weight:600}@media (max-width:575.98px){.modalConfirmationButton{width:100%;margin-bottom:15px}.modalConfirmationButton:first-of-type{-webkit-box-ordinal-group:2;-ms-flex-order:1;order:1}.modalConfirmationButton:last-of-type{-webkit-box-ordinal-group:1;-ms-flex-order:0;order:0;margin-bottom:1rem}}.modalConfirmationButton.primary{border-color:#407ab1;background:#407ab1;font-weight:300;color:#fff}.modalConfirmationButton.primary:hover{border-color:#27649e;background-color:#27649e}.modalConfirmationButton:focus{outline:none}.sidenav{position:fixed;display:none;top:0;right:0;height:100%;width:375px;overflow-x:hidden;background-color:#fff;z-index:0}.sidenav .card{height:100%;width:100%;border:none;background-color:#fff}.sidenav .card-header.close{background-color:transparent;border-bottom:1px solid rgba(0,0,0,.125)}.sidenav .card-header .close-legend:not(:disabled):not(.disabled) {line-height:1rem}.sidenav .card-header .close-legend:not(:disabled):not(.disabled) > span {line-height:1rem}.sidenav .card-header .close-legend:not(:disabled):not(.disabled) > span > span {position:relative;top:-1px}@-webkit-keyframes sidenav_open { 0% { right: -375px; }
#   100% { right: 0; } }@-moz-keyframes sidenav_open { 0% { right: -375px; }
#   100% { right: 0; } }@-ms-keyframes sidenav_open { .sidenav.no-push.active 0% { right: -375px; }
#   .sidenav.no-push.active 100% { right: 0; } }@keyframes sidenav_open { 0% { right: -375px; }
#   100% { right: 0; } }@-webkit-keyframes sidenav_close { 0% { right: 0; }
#   100% { right: -375px; } }@-moz-keyframes sidenav_close { 0% { right: 0; }
#   100% { right: -375px; } }@-ms-keyframes sidenav_close { .sidenav.no-push.active.nonactive 0% { right: 0; }
#   .sidenav.no-push.active.nonactive 100% { right: -375px; } }@keyframes sidenav_close { 0% { right: 0; }
#   100% { right: -375px; } }#sidenavWrapper{position:relative;-webkit-transition:-webkit-transform .5s;transition:-webkit-transform .5s;-o-transition:transform .5s;transition:transform .5s;transition:transform .5s , -webkit-transform .5s;z-index:1;left:0}@-webkit-keyframes sidenavWrapper_open { 0% { left: 0; }
#   100% { left: -375px; } }@-moz-keyframes sidenavWrapper_open { 0% { left: 0; }
#   100% { left: -375px; } }@-ms-keyframes sidenavWrapper_open { #sidenavWrapper.active 0% { left: 0; }
#   #sidenavWrapper.active 100% { left: -375px; } }@keyframes sidenavWrapper_open { 0% { left: 0; }
#   100% { left: -375px; } }@media (max-width:767.98px){@-webkit-keyframes sidenavWrapper_open { 0% { left: 0; }
#     100% { left: -100%; } }@-moz-keyframes sidenavWrapper_open { 0% { left: 0; }
#     100% { left: -100%; } }@-ms-keyframes sidenavWrapper_open { #sidenavWrapper.active 0% { left: 0; }
#     #sidenavWrapper.active 100% { left: -100%; } }@keyframes sidenavWrapper_open { 0% { left: 0; }
#     100% { left: -100%; } }}@-webkit-keyframes headerMain_open { 0% { left: 0;
#     right: 0; }
#   100% { left: -377px;
#     right: 375px; } }@-moz-keyframes headerMain_open { 0% { left: 0;
#     right: 0; }
#   100% { left: -377px;
#     right: 375px; } }@-ms-keyframes headerMain_open { #sidenavWrapper.active .headerMain 0% { left: 0; right: 0; }
#   #sidenavWrapper.active .headerMain 100% { left: -377px; right: 375px; } }@keyframes headerMain_open { 0% { left: 0;
#     right: 0; }
#   100% { left: -377px;
#     right: 375px; } }@media (max-width:767.98px){@-webkit-keyframes headerMain_open { 0% { left: 0;
#       right: 0; }
#     100% { left: calc( -100% + 2px);
#       right: 100%; } }@-moz-keyframes headerMain_open { 0% { left: 0;
#       right: 0; }
#     100% { left: calc( -100% + 2px);
#       right: 100%; } }@-ms-keyframes headerMain_open { #sidenavWrapper.active .headerMain 0% { left: 0; right: 0; }
#     #sidenavWrapper.active .headerMain 100% { left: calc( -100% + 2px); right: 100%; } }@keyframes headerMain_open { 0% { left: 0;
#       right: 0; }
#     100% { left: calc( -100% + 2px);
#       right: 100%; } }}@-webkit-keyframes sidenavWrapper_close { 0% { left: -375px; }
#   100% { left: 0; } }@-moz-keyframes sidenavWrapper_close { 0% { left: -375px; }
#   100% { left: 0; } }@-ms-keyframes sidenavWrapper_close { #sidenavWrapper.nonactive 0% { left: -375px; }
#   #sidenavWrapper.nonactive 100% { left: 0; } }@keyframes sidenavWrapper_close { 0% { left: -375px; }
#   100% { left: 0; } }@-webkit-keyframes headerMain_close { 0% { left: -375px;
#     right: 375px; }
#   100% { left: 0;
#     right: 0; } }@-moz-keyframes headerMain_close { 0% { left: -375px;
#     right: 375px; }
#   100% { left: 0;
#     right: 0; } }@-ms-keyframes headerMain_close { #sidenavWrapper.nonactive .headerMain 0% { left: -375px; right: 375px; }
#   #sidenavWrapper.nonactive .headerMain 100% { left: 0; right: 0; } }@keyframes headerMain_close { 0% { left: -375px;
#     right: 375px; }
#   100% { left: 0;
#     right: 0; } }#sidenavBlocker{top:0;left:0;width:100%;height:100%;position:fixed;z-index:99;-webkit-transition:all .5s;-o-transition:all .5s;transition:all .5s;display:none}@-webkit-keyframes sidenavBlocker { 0% { left: 0; }
#   100% { left: -375px; } }@-moz-keyframes sidenavBlocker { 0% { left: 0; }
#   100% { left: -375px; } }@-ms-keyframes sidenavBlocker { #sidenavBlocker.active 0% { left: 0; }
#   #sidenavBlocker.active 100% { left: -375px; } }@keyframes sidenavBlocker { 0% { left: 0; }
#   100% { left: -375px; } }@media (max-width:767.98px){#modal{padding-right:0!important}}#modal .modal-content{position:relative;min-height:200px}</style> <style>.itemPriceBox .itemNormalPrice{line-height:1;font-weight:bold;color:#000;margin-bottom:.25rem}@media (max-width:767.98px){.itemPriceBox .itemNormalPrice{font-size:1rem;margin:.5rem 0}}@-webkit-keyframes sk-cubeGridScaleDelay { 0%, 70%, 100% { -webkit-transform: scale3D(1, 1, 1);
#     transform: scale3D(1, 1, 1); }
#   35% { -webkit-transform: scale3D(0, 0, 1);
#     transform: scale3D(0, 0, 1); } }@keyframes sk-cubeGridScaleDelay { 0%, 70%, 100% { -webkit-transform: scale3D(1, 1, 1);
#     transform: scale3D(1, 1, 1); }
#   35% { -webkit-transform: scale3D(0, 0, 1);
#     transform: scale3D(0, 0, 1); } }@-webkit-keyframes sk-bouncedelay { 0%, 80%, 100% { -webkit-transform: scale(0); }
#   40% { -webkit-transform: scale(1); } }@keyframes sk-bouncedelay { 0%, 80%, 100% { -webkit-transform: scale(0);
#     transform: scale(0); }
#   40% { -webkit-transform: scale(1);
#     transform: scale(1); } }@-webkit-keyframes sk-rotate { 100% { -webkit-transform: rotate(360deg); } }@keyframes sk-rotate { 100% { transform: rotate(360deg);
#     -webkit-transform: rotate(360deg); } }@-webkit-keyframes sk-bounce { 0%, 100% { -webkit-transform: scale(0); }
#   50% { -webkit-transform: scale(1); } }@keyframes sk-bounce { 0%, 100% { transform: scale(0);
#     -webkit-transform: scale(0); }
#   50% { transform: scale(1);
#     -webkit-transform: scale(1); } }@-webkit-keyframes sk-rotateplane { 0% { -webkit-transform: perspective(120px); }
#   50% { -webkit-transform: perspective(120px) rotateY(180deg); }
#   100% { -webkit-transform: perspective(120px) rotateY(180deg) rotateX(180deg); } }@keyframes sk-rotateplane { 0% { transform: perspective(120px) rotateX(0deg) rotateY(0deg);
#     -webkit-transform: perspective(120px) rotateX(0deg) rotateY(0deg); }
#   50% { transform: perspective(120px) rotateX(-180.1deg) rotateY(0deg);
#     -webkit-transform: perspective(120px) rotateX(-180.1deg) rotateY(0deg); }
#   100% { transform: perspective(120px) rotateX(-180deg) rotateY(-179.9deg);
#     -webkit-transform: perspective(120px) rotateX(-180deg) rotateY(-179.9deg); } }@-webkit-keyframes sk-cubemove { 25% { -webkit-transform: translateX(42px) rotate(-90deg) scale(0.5); }
#   50% { -webkit-transform: translateX(42px) translateY(42px) rotate(-180deg); }
#   75% { -webkit-transform: translateX(0px) translateY(42px) rotate(-270deg) scale(0.5); }
#   100% { -webkit-transform: rotate(-360deg); } }@keyframes sk-cubemove { 25% { transform: translateX(42px) rotate(-90deg) scale(0.5);
#     -webkit-transform: translateX(42px) rotate(-90deg) scale(0.5); }
#   50% { transform: translateX(42px) translateY(42px) rotate(-179deg);
#     -webkit-transform: translateX(42px) translateY(42px) rotate(-179deg); }
#   50.1% { transform: translateX(42px) translateY(42px) rotate(-180deg);
#     -webkit-transform: translateX(42px) translateY(42px) rotate(-180deg); }
#   75% { transform: translateX(0px) translateY(42px) rotate(-270deg) scale(0.5);
#     -webkit-transform: translateX(0px) translateY(42px) rotate(-270deg) scale(0.5); }
#   100% { transform: rotate(-360deg);
#     -webkit-transform: rotate(-360deg); } }@-webkit-keyframes sk-bounce { 0%, 100% { -webkit-transform: scale(0); }
#   50% { -webkit-transform: scale(1); } }@keyframes sk-bounce { 0%, 100% { transform: scale(0);
#     -webkit-transform: scale(0); }
#   50% { transform: scale(1);
#     -webkit-transform: scale(1); } }@-webkit-keyframes sk-scaleout { 0% { -webkit-transform: scale(0); }
#   100% { -webkit-transform: scale(1);
#     opacity: 0; } }@keyframes sk-scaleout { 0% { -webkit-transform: scale(0);
#     transform: scale(0); }
#   100% { -webkit-transform: scale(1);
#     transform: scale(1);
#     opacity: 0; } }@-webkit-keyframes sk-stretchdelay { 0%, 40%, 100% { -webkit-transform: scaleY(0.4); }
#   20% { -webkit-transform: scaleY(1); } }@keyframes sk-stretchdelay { 0%, 40%, 100% { transform: scaleY(0.4);
#     -webkit-transform: scaleY(0.4); }
#   20% { transform: scaleY(1);
#     -webkit-transform: scaleY(1); } }</style>
# <style>.icheck label{display:inline-block;vertical-align:middle;font-weight:normal;margin-bottom:0}.icheck.icheckCustome label{display:inline}.icheckbox_minimal-blue{display:inline-block;*display: inline;vertical-align:middle;margin:0;padding:0;width:18px;height:18px;background:url(/webroot/img/icheck/minimal/minimal.png) no-repeat;border:none;cursor:pointer}.icheckbox_minimal-blue{background:url(/webroot/img/icheck/minimal/blue.png) no-repeat}.icheckbox_minimal-blue{background-position:0 0}@media (-o-min-device-pixel-ratio:5 / 4),(-webkit-min-device-pixel-ratio:1.25),(-o-min-device-pixel-ratio:5/4),(min-resolution:120dpi),(min-resolution:1.25dppx){.icheckbox_minimal-blue{-webkit-background-size:200px 20px;background-size:200px 20px}.icheckbox_minimal-blue{background-image:url(/webroot/img/icheck/minimal/blue@2x.png)}}.icheckbox_flat-aero{display:inline-block;*display: inline;vertical-align:middle;margin:0;padding:0;width:20px;height:20px;background:url(/webroot/img/icheck/flat/flat.png) no-repeat;border:none;cursor:pointer}.icheckbox_flat-aero{background:url(/webroot/img/icheck/flat/aero.png) no-repeat}.icheckbox_flat-aero{background-position:0 0}@media (-o-min-device-pixel-ratio:5 / 4),(-webkit-min-device-pixel-ratio:1.25),(-o-min-device-pixel-ratio:5/4),(min-resolution:120dpi),(min-resolution:1.25dppx){.icheckbox_flat-aero{-webkit-background-size:176px 22px;background-size:176px 22px}.icheckbox_flat-aero{background-image:url(/webroot/img/icheck/flat/aero@2x.png)}}.cc-window{opacity:1;transition:opacity 1s ease}.cc-window.cc-invisible{opacity:0}.cc-link{text-decoration:underline}.cc-window{position:relative;overflow:hidden;box-sizing:border-box;font-family:Helvetica,Calibri,Arial,sans-serif;font-size:12px;line-height:1.5em;display:-ms-flexbox;display:flex;-ms-flex-wrap:nowrap;flex-wrap:nowrap;z-index:9999}.cc-window.cc-banner{padding:1em 1.8em;width:100%;-ms-flex-direction:row;flex-direction:row}.cc-btn,.cc-link{cursor:pointer}.cc-link{opacity:.8;display:inline-block;padding:.2em}.cc-link:hover{opacity:1}.cc-link:active,.cc-link:visited{color:initial}.cc-btn{display:block;padding:.4em .8em;font-size:.9em;font-weight:700;border-width:2px;border-style:solid;text-align:center;white-space:nowrap}.cc-top{top:1em}.cc-window.cc-banner{-ms-flex-align:center;align-items:center}.cc-banner.cc-top{left:0;right:0;top:0}.cc-banner .cc-message{display:block;-ms-flex:1 1 auto;flex:1 1 auto;max-width:100%;margin-right:1em}.cc-compliance{align-self:center;display:-ms-flexbox;display:flex;-ms-flex-align:center;align-items:center;-ms-flex-line-pack:justify;align-content:space-between}@media screen and (max-width:900px){.cc-btn{white-space:normal}}@media screen and (max-width:414px) and (orientation:portrait),screen and (max-width:736px) and (orientation:landscape){.cc-window.cc-top{top:0}.cc-window.cc-banner{left:0;right:0}.cc-window.cc-banner{-ms-flex-direction:column;flex-direction:column}.cc-window.cc-banner .cc-compliance{-ms-flex:1 1 auto;flex:1 1 auto}.cc-window .cc-message{margin-bottom:1em}.cc-window.cc-banner{-ms-flex-align:unset;align-items:unset}.cc-window.cc-banner .cc-message{margin-right:0}}.cc-theme-classic .cc-btn{border-radius:5px}.cc-theme-classic .cc-btn:last-child{min-width:140px}</style>
# <style>@charset "UTF-8";.socialNetworks .navbar{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center}.socialNetworks .navbar .navbar-brand{-ms-flex-preferred-size:100%;flex-basis:100%;text-align:center;margin-bottom:0}@media (min-width:768px){.socialNetworks .navbar .navbar-brand{-ms-flex-preferred-size:auto;flex-basis:auto}}.socialNetworks .navbar .nav-item{text-decoration:none;margin:.5rem;-ms-flex-preferred-size:auto;flex-basis:auto}@media (min-width:576px){.socialNetworks .navbar .nav-item{-ms-flex-preferred-size:auto;flex-basis:auto}}.socialNetworks .navbar .nav-item:hover{-webkit-transform:scale(1.1,1.1);-ms-transform:scale(1.1,1.1);transform:scale(1.1,1.1)}.socialNetworks .navbar .nav-item span{border-radius:8px;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;width:40px;height:40px;margin:0 auto}.socialNetworks .navbar .nav-item span:after{line-height:40px}.socialNetworks .navbar .nav-item.facebook span{background-color:#33548e}.socialNetworks .navbar .nav-item.facebook span:after{content:"";font-size:1.8em;color:#fff;font-family:FontAwesome;font-style:normal;font-weight:normal;display:inline-block}.socialNetworks .navbar .nav-item.instagram span{background:gray;background:-moz-linear-gradient(45deg,#fcd03c 0%,#f6000d 50%,#b219a7 100%);background:-webkit-linear-gradient(45deg,#fcd03c 0%,#f6000d 50%,#b219a7 100%);background:-o-linear-gradient(45deg,#fcd03c 0%,#f6000d 50%,#b219a7 100%);background:linear-gradient(45deg,#fcd03c 0%,#f6000d 50%,#b219a7 100%);filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcd03c', endColorstr='#b219a7',GradientType=1 )}.socialNetworks .navbar .nav-item.instagram span:after{content:"";font-size:1.8em;color:#fff;font-family:FontAwesome;font-style:normal;font-weight:normal;display:inline-block}.socialNetworks .navbar .nav-item.pinterest span{background-color:#b80b1c}.socialNetworks .navbar .nav-item.pinterest span:after{content:"";font-size:1.8em;color:#fff;font-family:FontAwesome;font-style:normal;font-weight:normal;display:inline-block}.socialNetworks .navbar .nav-item.twitter span{background-color:#009bed}.socialNetworks .navbar .nav-item.twitter span:after{content:"";font-size:1.8em;color:#fff;font-family:FontAwesome;font-style:normal;font-weight:normal;display:inline-block}.socialNetworks .navbar .nav-item.youtube span{background-color:#ff000f}.socialNetworks .navbar .nav-item.youtube span:after{content:"";font-size:1.8em;color:#fff;font-family:FontAwesome;font-style:normal;font-weight:normal;display:inline-block}</style>
# <style>@font-face{font-family:"slick";src:url(/webroot/fonts/slick/slick.eot);src:url(/webroot/fonts/slick/slick.eot?#iefix) format("embedded-opentype") , url(/webroot/fonts/slick/slick.woff) format("woff") , url(/webroot/fonts/slick/slick.ttf) format("truetype") , url(/webroot/fonts/slick/slick.svg#slick) format("svg");font-weight:normal;font-style:normal}@charset "UTF-8";</style> <style>.ui-helper-hidden-accessible{border:0;clip:rect(0 0 0 0);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px}.ui-front{z-index:100}.ui-autocomplete{position:absolute;top:0;left:0;cursor:default}.ui-menu{list-style:none;padding:0;margin:0;display:block;outline:0}.ui-widget{font-size:.875rem}.ui-widget.ui-widget-content{border:1px solid #c5c5c5}.ui-widget-content{border:1px solid #ddd;background:#fff;color:#333}@charset "UTF-8";.socialNetworks .navbar{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center}.socialNetworks .navbar .navbar-brand{-ms-flex-preferred-size:100%;flex-basis:100%;text-align:center;margin-bottom:0}@media (min-width:768px){.socialNetworks .navbar .navbar-brand{-ms-flex-preferred-size:auto;flex-basis:auto}}.socialNetworks .navbar .nav-item{text-decoration:none;margin:.5rem;-ms-flex-preferred-size:auto;flex-basis:auto}@media (min-width:576px){.socialNetworks .navbar .nav-item{-ms-flex-preferred-size:auto;flex-basis:auto}}.socialNetworks .navbar .nav-item:hover{-webkit-transform:scale(1.1,1.1);-ms-transform:scale(1.1,1.1);transform:scale(1.1,1.1)}.socialNetworks .navbar .nav-item span{border-radius:8px;display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;width:40px;height:40px;margin:0 auto}.socialNetworks .navbar .nav-item span:after{line-height:40px}.socialNetworks .navbar .nav-item.facebook span{background-color:#33548e}.socialNetworks .navbar .nav-item.facebook span:after{content:"";font-size:1.8em;color:#fff;font-family:FontAwesome;font-style:normal;font-weight:normal;display:inline-block}.socialNetworks .navbar .nav-item.instagram span{background:gray;background:-moz-linear-gradient(45deg,#fcd03c 0%,#f6000d 50%,#b219a7 100%);background:-webkit-linear-gradient(45deg,#fcd03c 0%,#f6000d 50%,#b219a7 100%);background:-o-linear-gradient(45deg,#fcd03c 0%,#f6000d 50%,#b219a7 100%);background:linear-gradient(45deg,#fcd03c 0%,#f6000d 50%,#b219a7 100%);filter: progid:DXImageTransform.Microsoft.gradient( startColorstr='#fcd03c', endColorstr='#b219a7',GradientType=1 )}.socialNetworks .navbar .nav-item.instagram span:after{content:"";font-size:1.8em;color:#fff;font-family:FontAwesome;font-style:normal;font-weight:normal;display:inline-block}.socialNetworks .navbar .nav-item.pinterest span{background-color:#b80b1c}.socialNetworks .navbar .nav-item.pinterest span:after{content:"";font-size:1.8em;color:#fff;font-family:FontAwesome;font-style:normal;font-weight:normal;display:inline-block}.socialNetworks .navbar .nav-item.twitter span{background-color:#009bed}.socialNetworks .navbar .nav-item.twitter span:after{content:"";font-size:1.8em;color:#fff;font-family:FontAwesome;font-style:normal;font-weight:normal;display:inline-block}.socialNetworks .navbar .nav-item.youtube span{background-color:#ff000f}.socialNetworks .navbar .nav-item.youtube span:after{content:"";font-size:1.8em;color:#fff;font-family:FontAwesome;font-style:normal;font-weight:normal;display:inline-block}</style>
# <style>.productList-hero .productList-hero_menu{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;justify-content:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-ms-flex-wrap:wrap;flex-wrap:wrap;list-style:none;margin-bottom:0;padding:0;max-width:850px;margin:auto}.productList-hero .productList-hero_menu .item{margin:.5rem 1rem;color:#343a40;min-width:10%;text-align:center}.productList-hero .productList-hero_menu .item.active{font-weight:600}.productList-hero .productList-hero_menu .item a{color:#343a40}.productList{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-align:stretch;-ms-flex-align:stretch;align-items:stretch}.productList .card{height:100%;border:none;padding-bottom:2rem}.productList .card-header{background-color:#fff;border-bottom:none;padding:1.25rem;position:relative}.productList .card-header .itemBadges{position:absolute;bottom:0;left:1.25rem}.productList .card-header .productImg{padding-bottom:100%;height:0}.productList .card-header .card-img-top{position:inherit}.productList .card-header .card-img-top:after{position:absolute;top:50%;left:50%;padding:0;margin-top:-1.5rem;margin-left:-1.5rem}.productList .card-body{padding:0 1.25rem}.productList .card-footer{background-color:#fff;border-top:none;padding:1.25rem}@media (max-width:767.98px){.productList .card-footer{padding:.8rem}}.productList .itemMore{font-size:.8rem;margin:0}@media (max-width:767.98px){.productList .itemMore{font-size:.65rem;margin:0}}.see-only{cursor:pointer;position:relative}.see-only .chevron-see-only{font-size:.8rem}.see-only .chevron-see-only:before{-webkit-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);-webkit-transition:-webkit-transform .3s ease-out;transition:-webkit-transform .3s ease-out;-o-transition:transform .3s ease-out;transition:transform .3s ease-out;transition:transform .3s ease-out , -webkit-transform .3s ease-out}@media (max-width:991.98px){.see-only #newFilters{position:absolute;top:100%;right:0;color:#212529;text-align:left;list-style:none;background-color:#fff;background-clip:padding-box;border:1px solid rgba(0,0,0,.15);border-radius:.25rem;z-index:1000;padding:.5rem 1.5rem;margin:.125rem 0 0}}.productList .card-header .itemBadges{position:absolute;bottom:0;left:1.25rem}.itemInfo{}.itemInfo .itemPrice-wrapper{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-orient:horizontal;-webkit-box-direction:normal;-ms-flex-direction:row;flex-direction:row;-webkit-box-align:center;-ms-flex-align:center;align-items:center}.itemInfo .itemName{color:#212529;display:block;font-weight:bold}.itemInfo .itemName h6{margin-bottom:0}@media (max-width:767.98px){.itemInfo .itemName h6{font-size:1rem}}.itemInfo .itemDetails{min-height:30px}.itemInfo .itemFacts{font-size:1rem;margin:0;margin-bottom:.25rem}@media (max-width:767.98px){.itemInfo .itemFacts{display:block;font-size:.86rem;margin:0;margin-bottom:.25rem;max-width:100%;overflow:hidden;white-space:nowrap;-o-text-overflow:ellipsis;text-overflow:ellipsis}}@media (max-width:575.98px){.itemInfo{margin-bottom:1.5rem}}</style> <style>.filters{margin:1.5rem 0;padding:0}.filters ul{margin:0;padding:0;width:100%}.filters li{width:100%;padding:.5rem 1rem}@media (min-width:768px){.filters li{padding:.5rem 2rem}.filters .filterSelector{border-left:none;border-right:none;display:block}}.filters .filterToggler{display:-webkit-box;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-ms-flex-pack:end;justify-content:flex-end;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#6c757d;margin-bottom:1rem;text-decoration:none;border:1px solid #ced4da;background:#f5f5f5;padding:10px 15px;width:100%}.filters .filterToggler span:before{font-size:inherit;color:inherit;display:inline-block;vertical-align:middle;padding:0 .50rem 0 0}.filters .filterToggler:hover{color:#343a40}@media (min-width:768px){.filters .filterToggler{display:none}}.filters .filterWrapper .filterCo ...
# <style>.itemSelector .content:last-of-type:not(.border-bottom) {border-bottom:1px solid transparent}.itemCounter .value .val :not(input) {width:initial}</style> <style>.quickLook:hover, .quickLook:not(:disabled):not(.disabled):active {color:#343a40;background:#ced4da;border-color:#ced4da}.quickLook{width:100%;background:transparent;border:1px solid #ced4da;padding-top:.45rem;padding-bottom:.45rem;padding-left:1rem;padding-right:1rem;color:#6c757d}@media (min-width:576px){.quickLook{padding-left:3rem;padding-right:3rem}}.quickLook:not(:disabled):not(.disabled):active {color:#222}.addToProduct span:not(.icon), .unselectToProduct span:not(.icon) {font-weight:600}.modalConfirmationButton{color:#000;background:transparent;border:1px solid #000;margin:0;padding:8px 20px;font-weight:600}@media (max-width:575.98px){.modalConfirmationButton{width:100%;margin-bottom:15px}.modalConfirmationButton:first-of-type{-webkit-box-ordinal-group:2;-ms-flex-order:1;order:1}.modalConfirmationButton:last-of-type{-webkit-box-ordinal-group:1;-ms-flex-order:0;order:0;margin-bottom:1rem}}.modalConfirmationButton.primary{border-color:#407ab1;background:#407ab1;font-weight:300;color:#fff}.modalConfirmationButton.primary:hover{border-color:#27649e;background-color:#27649e}.modalConfirmationButton:focus{outline:none}.pagination .page-item{padding:0}.pagination .page-item .page-link{border:1px solid #ddd;border-radius:3px;padding:8px 10px;margin:0 3px;font-size:.9rem;line-height:.9rem}@media (max-width:767.98px){.pagination .page-item .page-link{padding:4px 5px;font-size:.8rem}}.pagination .page-item .page-link:hover{background:#f7f7f7}.pagination .page-item.active .page-link{border:0;font-weight:600;color:#222;background:transparent}.pagination .page-item.next{border:0}.pagination .page-item.next .page-link{font-size:.8rem;border:0}.pagination .page-item.next .page-link:hover{background:transparent}.pagination .page-item.next a{text-decoration:none}.pagination .page-item.dots .page-link{padding:8px 2px;border:0}</style>
# <link href="/webroot/img/favicon_16px.png" rel="icon"/>
# <link href="/webroot/img/favicon_32px.png" rel="icon"/>
# <link href="/webroot/img/favicon_48px.png" rel="icon"/>
# <!-- Page hiding snippet (recommended) -->
# <style>.async-hide{opacity:0!important}</style>
# <script src="//tags.tiqcdn.com/utag/xaxis/-ikea/prod/utag.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/plugins/ua/ec.js" type="text/javascript"></script><script id="tealium_controler_1186823076" src="https://tags.tiqcdn.com/utag/xaxis/ikea.co.id/prod/utag.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/gtm/js?id=GTM-PRZCBBC&amp;t=gtm1&amp;cid=133463414.1579847256" type="text/javascript"></script><script async="" src="https://connect.facebook.net/signals/config/368630343752849?v=2.9.15&amp;r=stable"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script id="lightning_bolt_1594616633" src="https://cdn-akamai.mookie1.com/LB/LightningBolt.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="//static.hotjar.com/c/hotjar-1106945.js?sv=5" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//assets.pinterest.com/js/pinit_main.js?0.8544216525954931" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-PZQ5DRN&amp;gtm_auth=R-z9I8AAYZXD6bORF_CoWg&amp;gtm_preview=env-2&amp;gtm_cookies_win=x"></script><script>(function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};(a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);})(window,document.documentElement,'async-hide','dataLayer',4000,{'GTM-PZQ5DRN':true});window.dataLayer=window.dataLayer||[];window.dataLayer.push({userId:0});(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl+'&gtm_auth=R-z9I8AAYZXD6bORF_CoWg&gtm_preview=env-2&gtm_cookies_win=x';f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-PZQ5DRN');</script>
# <!-- End Google Tag Manager -->
# <style></style><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/956855798/?random=1579847256373&amp;cv=9&amp;fst=1579847256373&amp;num=1&amp;label=jSOECIjKjGIQ9uuhyAM&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=768&amp;u_w=1366&amp;u_ah=728&amp;u_aw=1366&amp;u_cd=24&amp;u_his=2&amp;u_tz=420&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg1f1&amp;sendb=1&amp;ig=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.ikea.co.id%2Fin%2Fsearch%2F%3Fq%3Dmeja&amp;tiba=Hasil%20Pencarian%20untuk%20meja%20%7C%20IKEA%20Indonesia&amp;hn=www.googleadservices.com&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script async="" charset="utf-8" src="https://script.hotjar.com/modules.4fbc6fa978838a77e880.js"></script><style type="text/css">iframe#_hjRemoteVarsFrame {display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;}</style><style type="text/css"> span.PIN_1579847255328_embed_grid {
#   width: 100%;
#   max-width: 257px;
#   min-width: 140px;
#   display: inline-block;
#   box-shadow: inset 0 0 1px #000;
#   border-radius: 5px;
#   overflow: hidden;
#   font: 12px "Helvetica Neue", Helvetica, arial, sans-serif;
#   color: rgb(54, 54, 54);
#   box-sizing: border-box;
#   background: #fff;
#   cursor: pointer;
#   -webkit-font-smoothing: antialiased;
# }
#  span.PIN_1579847255328_embed_grid * {
#   display: block;
#   position: relative;
#   font: inherit;
#   cursor: inherit;
#   color: inherit;
#   box-sizing: inherit;
#   margin: 0;
#   padding: 0;
#   text-align: left;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_hd {
#   height: 55px;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_hd .PIN_1579847255328_img {
#   position: absolute;
#   top: 10px;
#   left: 10px;
#   height: 36px;
#   width: 36px;
#   border-radius: 18px;
#   background: transparent url () 0 0 no-repeat;
#   background-size: cover;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_hd .PIN_1579847255328_pinner {
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
#   width: 75%;
#   position: absolute;
#   top: 20px;
#   left: 56px;
#   font-size: 14px;
#   font-weight: bold;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_bd {
#   padding: 0 10px;
#   -moz-scrollbars: none;
#   -ms-overflow-style: none;
#   overflow-x: hidden;
#   overflow-y: auto;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_bd .PIN_1579847255328_ct {
#   width: 100%;
#   height: auto;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_bd .PIN_1579847255328_ct .PIN_1579847255328_col {
#   display: inline-block;
#   width: 100%;
#   padding: 1px;
#   vertical-align: top;
#   min-width: 60px;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_bd .PIN_1579847255328_ct .PIN_1579847255328_col .PIN_1579847255328_img {
#   margin: 0;
#   display: inline-block;
#   width: 100%;
#   background: transparent url() 0 0 no-repeat;
#   background-size: cover;
#   box-shadow: inset 0 0 1px #000;
#   border-radius: 2px;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_ft {
#   padding: 11px;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_ft .PIN_1579847255328_button {
#   border-radius: 3px;
#   text-align: center;
#   box-shadow: inset 0 0 1px #888;
#   background-color: #efefef;
#   position: relative;
#   display: block;
#   overflow: hidden;
#   height: 33px;
#   width: 100%;
#   min-width: 70px;
#   padding: 0 3px;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_ft .PIN_1579847255328_button .PIN_1579847255328_label {
#   position: absolute;
#   left: 0;
#   width: 100%;
#   text-align: center;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_ft .PIN_1579847255328_button .PIN_1579847255328_label.PIN_1579847255328_top {
#   top: 0;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_ft .PIN_1579847255328_button .PIN_1579847255328_label.PIN_1579847255328_bottom {
#   bottom: 0;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_ft .PIN_1579847255328_button .PIN_1579847255328_label .PIN_1579847255328_string {
#   white-space: pre;
#   color: #746d6a;
#   font-size: 13px;
#   font-weight: bold;
#   vertical-align: top;
#   display: inline-block;
#   height: 33px;
#   line-height: 33px;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_ft .PIN_1579847255328_button .PIN_1579847255328_label .PIN_1579847255328_logo {
#   display: inline-block;
#   vertical-align: bottom;
#   height: 32px;
#   width: 80px;
#   background: transparent url(data:image/svg+xml;base64,...) 50% 50% no-repeat;
#   background-size: contain;
# }
#  span.PIN_1579847255328_embed_grid .PIN_1579847255328_ft .PIN_1579847255328_button:hover {
#   box-shadow: inset 0 0 1px #000;
# }
#  span.PIN_1579847255328_embed_grid.PIN_1579847255328_noscroll .PIN_1579847255328_bd {
#   overflow: hidden;
# }
#  span.PIN_1579847255328_embed_grid.PIN_1579847255328_board .PIN_1579847255328_hd .PIN_1579847255328_pinner {
#   top: 10px;
# }
#  span.PIN_1579847255328_embed_grid.PIN_1579847255328_board .PIN_1579847255328_hd .PIN_1579847255328_board {
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
#   width: 75%;
#   position: absolute;
#   bottom: 10px;
#   left: 56px;
#   color: #363636;
#   font-size: 12px;
# }
#  span.PIN_1579847255328_embed_grid.PIN_1579847255328_c2 {
#   max-width: 494px;
#   min-width: 140px;
# }
#  span.PIN_1579847255328_embed_grid.PIN_1579847255328_c2 .PIN_1579847255328_bd .PIN_1579847255328_ct .PIN_1579847255328_col {
#   width: 50%;
# }
#  span.PIN_1579847255328_embed_grid.PIN_1579847255328_c3 {
#   max-width: 731px;
#   min-width: 200px;
# }
#  span.PIN_1579847255328_embed_grid.PIN_1579847255328_c3 .PIN_1579847255328_bd .PIN_1579847255328_ct .PIN_1579847255328_col {
#   width: 33.33%;
# }
#  span.PIN_1579847255328_embed_grid.PIN_1579847255328_c4 {
#   max-width: 968px;
#   min-width: 260px;
# }
#  span.PIN_1579847255328_embed_grid.PIN_1579847255328_c4 .PIN_1579847255328_bd .PIN_1579847255328_ct .PIN_1579847255328_col {
#   width: 25%;
# }
#  span.PIN_1579847255328_embed_grid.PIN_1579847255328_c5 {
#   max-width: 1205px;
#   min-width: 320px;
# }
#  span.PIN_1579847255328_embed_grid.PIN_1579847255328_c5 .PIN_1579847255328_bd .PIN_1579847255328_ct .PIN_1579847255328_col {
#   width: 20%;
# }
#  span.PIN_1579847255328_embed_grid.PIN_1579847255328_c6 {
#   max-width: 1442px;
# ...
#     @media (max-width: 991.98px) { .see-only #newFilters { position: absolute; top: 100%; right: 0; color: #212529; text-align: left; list-style: none; background-color: #fff; background-clip: padding-box; border: 1px solid rgba(0, 0, 0, 0.15); border-radius: 0.25rem; z-index: 1000; padding: 0.5rem 1.5rem; margin: 0.125rem 0 0; } }
# </style>
# <script id="" type="text/javascript">if("undefined"!==typeof best_seller_json_new){var parts=document.URL.split("/"),artnum_best,prodname_best,price_best,onclick_best,view_stat=[],jsonScrolled=[],nested_scrolled_best_seller=[],change=function(c){null===c?$("#best-seller-new").css("display","block"):$("#best-seller-new").remove()};$(window).on("pushState",function(c){change(c.originalEvent.state)});(function(c){history.pushState=function(b){change(b);return c.apply(this,arguments)}})(history.pushState);var count_best_seller=0,pos=1,array_temp=
# [],url_en_val=-1<document.URL.indexOf("ikea.co.id/en"),url_in_val=-1<document.URL.indexOf("ikea.co.id/in"),lang_vers="",title_best="",quick_view="",best_seller_new_val=url_en_val?(title_best="Best seller",lang_vers="en",quick_view="Quick View"):url_in_val?(title_best="Terlaris",lang_vers="in",quick_view="Lihat sekilas"):!1,best_seller_template=function(c){var b="";b+='\x3cdiv class\x3d"container"\x3e';b+='\x3cdiv class\x3d"row productList-new"\x3e';b+='\x3cdiv class\x3d"col-12 text-center"\x3e';b+=
# '\x3ch2 class\x3d"display-7"\x3e'+title_best+"\x3c/h2\x3e";b+="\x3c/div\x3e";for(var d=0;d<c.length;d++)b+='\x3cdiv class\x3d"col-6 col-md-3 col-lg-3 itemBlock"\x3e',b+='\x3cdiv class\x3d"card" id\x3d"prod-'+(d+1)+'"\x3e',b+='\x3cdiv class\x3d"card-header text-center"\x3e',b+='\x3ca class\x3d"itemName" href\x3d""\x3e',b+='\x3cdiv class\x3d"itemBadges"\x3e\x3c/div\x3e',b+='\x3cspan class\x3d"productImg"\x3e',b+='\x3cimg class\x3d"img-fluid" id\x3d"img-'+(d+1)+'" src\x3d"https://www.ikea.co.id/webroot/img/ajax-loader.gif"\x3e',
# b+="\x3c/span\x3e",b+="\x3c/a\x3e",b+="\x3c/div\x3e",b+="\x3c/div\x3e",b+="\x3c/div\x3e";b+="\x3c/div\x3e";b+="\x3c/div\x3e";$("#best-seller-new").append(b)},best_seller_new_body=function(c){$.ajax({url:"/"+lang_vers+"/catalog/products/"+c[count_best_seller].ArticleNumber+"?type\x3dxml\x26dataset\x3dnormal%2Cprices%2Callimages%2Cattributes",type:"GET",dataType:"xml",async:!0,error:function(){console.log(c[count_best_seller].ArticleNumber+" Failed")}}).done(function(b){b=(new XMLSerializer).serializeToString(b.documentElement);
# xmlDoc=$.parseXML(b);$xml=$(xmlDoc);$article=$xml.find("partNumber").eq(0).text();$name=$xml.find("name").eq(0).text();$desc=$xml.find("facts").eq(0).text();$url=$xml.find("URL").eq(0).text();$new=$xml.find("new").eq(0).text();$priceafter=$pricebefore="";""!=$xml.find("pricePrevious").eq(0).text()?$pricebefore=$xml.find("pricePrevious").eq(0).text():$xml.find("priceNormal").eq(0).text()!==c[count_best_seller].Price&&($pricebefore=c[count_best_seller].Price);$priceafter=$xml.find("priceNormal").eq(0).text();
# $bti=$xml.find("bti").eq(0).text();$show=$xml.find("browseable").eq(0).text();$buy=$xml.find("buyable").eq(0).text();$nlp=$xml.find("priceNormal").eq(0).attr("nlp");$image=$xml.find("normal").eq(0).children().eq(0).text();$pricebefore=$pricebefore.substr(0,$pricebefore.length-3);$priceafter=$priceafter.substr(0,$priceafter.length-3);b=$priceafter.replace("Rp ","").replace(/[\.]/gi,"");var d=document.URL.split("/"),a="",f="30445359 80439445 60439446 80439407 00439406 60439432 00439430 89305837 79305786 99305813 09300122 99305808 09311045 09304525 60432082 80431717 50373592 10373589 40265164 50291332 90350999 20353623 70353593 10353609 70353606 60350986 00350994 20353618 60353598 09188031 79250270 89228090 49188128 10408046 10408051 20408036 20408041 10408051 20408036 90348553 10348585 20348575 20244525 90244414 30244351 30269351 10269352 30244394 30244520 69217380 49217060 89217063 89217181 69217064 59216588 59217069 29217122 49217376 39216594 69217177 69216696 39216693 09303899 29284668 20428553 90428516 00348595 10238271 40266984 70355686 60355696 50355687 20357895 79285967 49127922 20358475 79127845 49127502 49246864 29303718 19266858 79246589 49244964 39244926 99300151 69127921 09244942 39218343 40355409 50338042 00347176 50381276 89241303 39241305 79009451 59019187 89027379 49227752 20372155 70372153 39124617 59200498 09200877 09241359 49241357 29241264 69241262 89200878 29200621 10423160 80423072 00423151 30406131 30406145 60406144 80423086 60423087 80423152 00341136 80423147 40423173 20423174 50344769 70400274 60347178 40439447 90353653 09306322 80439431 60439408 40353684 60353640 30353670 90353648 60353678 29188092 69188146 80244508 39244988 79029963 59266903 09289520 10399706 30399705 50399691 80406157 90406171 10406170".split(" ");
# "true"==$show?(a+='\x3cdiv class\x3d"card-header"\x3e',a+='\x3ca class\x3d"itemName" href\x3d"'+$url+'"\x3e',a+='\x3cdiv class\x3d"itemBadges"\x3e',"true"==$nlp&&f.includes($article)?a+='\x3cdiv id\x3d"lowerPrices" class\x3d"badge-lower-price"\x3e\x3cimg src\x3d"https://www.ikea.co.id/webroot/img/logos/newlowerprice_en.png" alt\x3d"New Lower Price"\x3e\x3c/div\x3e':"true"==$new&&(a+='\x3cdiv class\x3d"badge-new-circular"\x3e\x3cspan\x3eNEW\x3c/span\x3e\x3c/div\x3e'),a+="\x3c/div\x3e",a+='\x3cspan class\x3d"productImg"\x3e',
# a+='\x3cimg class\x3d"img-fluid lazyload" data-src\x3d"'+$image+'"\x3e',a+="\x3c/span\x3e",a+="\x3c/a\x3e",a+="\x3c/div\x3e",a+='\x3cdiv class\x3d"card-body"\x3e',a+='\x3cdiv class\x3d"itemInfo"\x3e',a+='\x3ca class\x3d"itemName" href\x3d"'+$url+'"\x3e',a+='\x3ch6 class\x3d"display-7"\x3e'+$name+"\x3c/h6\x3e",a+="\x3c/a\x3e",a+='\x3cp class\x3d"itemFacts"\x3e'+$desc+"\x3c/p\x3e",a+='\x3cdiv class\x3d"itemPriceBox"\x3e',"true"==$bti?(""!=$pricebefore?(a+='\x3cp class\x3d"itemOldPrice mb-2"\x3e',a+=
# '\x3cspan class\x3d"oldValue"\x3e'+$pricebefore+"\x3c/span\x3e",a+="\x3c/p\x3e",a+='\x3cdiv class\x3d"itemPrice-wrapper"\x3e',a+='\x3cp class\x3d"itemBTI itemOfferPrice display-7"\x3e'):(a+='\x3cdiv class\x3d"itemPrice-wrapper"\x3e',a+='\x3cp class\x3d"itemBTI display-7"\x3e'),a+='\x3cspan data-price\x3d"'+$priceafter+'"\x3e'+$priceafter+"\x3c/span\x3e",a+="\x3c/p\x3e"):""!=$pricebefore?(a+='\x3cdiv class\x3d"d-flex flex-column"\x3e',a+='\x3cp class\x3d"itemOldPrice mb-2"\x3e',a+='\x3cspan class\x3d"oldValue"\x3e'+
# $pricebefore+"\x3c/span\x3e",a+="\x3c/p\x3e",a+='\x3cdiv class\x3d"itemPrice-wrapper"\x3e',a+='\x3cp class\x3d"itemOfferPrice display-7"\x3e',a+='\x3cspan data-price\x3d"'+$priceafter+'"\x3e'+$priceafter+"\x3c/span\x3e",a+="\x3c/p\x3e",a+="\x3c/div\x3e"):(a+='\x3cdiv class\x3d"itemPrice-wrapper"\x3e',a+='\x3cp class\x3d"display-7"\x3e',a+='\x3cspan data-price\x3d"'+$priceafter+'"\x3e'+$priceafter+"\x3c/span\x3e",a+="\x3c/p\x3e"),a+="\x3c/div\x3e",a+="\x3c/div\x3e",a+="\x3c/div\x3e",a+="\x3c/div\x3e",
# a+='\x3cdiv class\x3d"card-footer"\x3e',"false"==$buy?(a+='\x3cdiv class\x3d"inStoreOnlyThumb btn btn-block btn-icon"\x3e',a+='\x3cspan class\x3d"picto-ikea-point"\x3e\x3c/span\x3e',a+="\x3cspan\x3eOnly available in-store\x3c/span\x3e",a+="\x3c/div\x3e"):(a+='\x3cbutton class\x3d"btn btn-outline-gray-medium mx-auto btn-icon sidenavItem quickLook" data-item\x3d"'+$article+'" data-action\x3d"sidenav"\x3e',a+='\x3cspan class\x3d"icon-quickview"\x3e\x26nbsp;\x3c/span\x3e',a+="\x3cspan\x3e"+quick_view+
# "\x3c/span\x3e",a+="\x3c/button\x3e"),a+="\x3c/div\x3e",$("#prod-"+(count_best_seller+1)).html(a),$("#prod-"+(count_best_seller+1)+" a").attr("onclick",'dataLayer.push({"event": "productclickgtm", "ecommerce": {"click": {"actionField": {"list": "best seller product"}, "products": [{"id": "'+$article+'", "name": "'+$name+" - "+$desc+'", "price": "'+b+'", "brand": "'+$name+'", "category": "'+d[d.length-1]+'", "position": "'+pos+'"}] } } });'),b={id:""+$article,name:""+$name+" - "+$desc,price:""+b,brand:""+
# $name,category:""+parts[parts.length-1],position:""+pos,status:"FALSE"},view_stat.push(b),pos++):($("#prod-"+(count_best_seller+1)).parent().remove(),console.log(count_best_seller+". This "+c[count_best_seller].ArticleNumber+" has been removed"))}).always(function(){count_best_seller++;count_best_seller!=c.length&&best_seller_new_body(c)})};$(document).ready(function(){$.fn.isInViewport=function(){var b=$(this).offset().top,d=b+$(this).outerHeight(),a=$(window).scrollTop(),c=a+$(window).height();
# return d>a&&b<c};var c=function(b){b={event:"productviewgtm",ecommerce:{currencyCode:"IDR",impressions:b}};dataLayer.push(b)};$(window).on("resize scroll",function(){$("#best-seller-new .col-6").each(function(b){if($(this).isInViewport()){if("FALSE"==view_stat[b].status){var d={id:""+view_stat[b].id,name:""+view_stat[b].name,price:""+view_stat[b].price,brand:""+view_stat[b].brand,category:""+parts[parts.length-1],position:""+(b+1),list:"best seller product"};jsonScrolled.push(d);view_stat[b].status=
# "TRUE"}}else view_stat[b].status="FALSE"});0!=jsonScrolled.length&&(c(jsonScrolled),jsonScrolled=[])});best_seller_template(best_seller_json_new);best_seller_new_body(best_seller_json_new)})}else"undefined"!==typeof best_seller_json&&(parts=document.URL.split("/"),view_stat=[],jsonScrolled=[],nested_scrolled_best_seller=[],$(document).ready(function(){var c=-1<document.URL.indexOf("ikea.co.id/en");document.URL.indexOf("ikea.co.id/in");$(best_seller_json).each(function(b,a){var d=c?a.Deskripsi_EN:
# a.Deskripsi_IN;a.PriceAfter=a.PriceAfter.replace("Rp ","").replace(/[\.]/gi,"");var e={id:""+a.ArticleNumber,name:""+a.ProductName+" - "+d,price:""+a.PriceAfter,brand:""+a.ProductName,category:""+parts[parts.length-1],position:""+(b+1),status:"FALSE"};view_stat.push(e);onclick_best={event:"productclickgtm",ecommerce:{click:{actionField:{list:"best seller product"},products:[{id:""+a.ArticleNumber,name:""+a.ProductName+" - "+d,price:""+a.PriceAfter,brand:""+a.ProductName,category:""+parts[parts.length-
# 1],position:""+(b+1)}]}}};$("#best-seller-new .productList-new .itemBlock:nth-child("+(b+2)+") .card").attr("onclick","dataLayer.push("+JSON.stringify(onclick_best)+")")});$.fn.isInViewport=function(){var b=$(this).offset().top,a=b+$(this).outerHeight(),c=$(window).scrollTop(),e=c+$(window).height();return a>c&&b<e};var b=function(b){b={event:"productviewgtm",ecommerce:{currencyCode:"IDR",impressions:b}};dataLayer.push(b)};$(window).on("resize scroll",function(){$("#best-seller-new .col-6").each(function(b){if($(this).isInViewport()){if("FALSE"==
# view_stat[b].status){var a={id:""+view_stat[b].id,name:""+view_stat[b].name,price:""+view_stat[b].price,brand:""+view_stat[b].brand,category:""+parts[parts.length-1],position:""+(b+1),list:"best seller product"};jsonScrolled.push(a);view_stat[b].status="TRUE"}}else view_stat[b].status="FALSE"});0!=jsonScrolled.length&&(b(jsonScrolled),jsonScrolled=[])})}));</script>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","368630343752849");fbq("set","agent","tmgoogletagmanager","368630343752849");fbq("track","PageView");</script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=368630343752849&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <script id="" type="text/javascript">!function(b,e,f,g,a,c,d){b.fbq||(a=b.fbq=function(){a.callMethod?a.callMethod.apply(a,arguments):a.queue.push(arguments)},b._fbq||(b._fbq=a),a.push=a,a.loaded=!0,a.version="2.0",a.queue=[],c=e.createElement(f),c.async=!0,c.src=g,d=e.getElementsByTagName(f)[0],d.parentNode.insertBefore(c,d))}(window,document,"script","https://connect.facebook.net/en_US/fbevents.js");fbq("init","368630343752849");fbq("track","PageView");
# fbq("track","Search",{search_string:google_tag_manager["GTM-PZQ5DRN"].macro(2),content_ids:google_tag_manager["GTM-PZQ5DRN"].macro(3),content_type:"product"});</script><iframe frameborder="0" height="1" scrolling="no" src="https://asia.creativecdn.com/tags?id=pr_r8nPB2daYJRpvLQ2eKQF_listing_334126%2C50452607%2C40452622%2C89240780%2C60423110" style="display: none;" width="1"></iframe><script charset="utf-8" id="PIN_1579847255328.f.callback[0]" src="https://log.pinterest.com/?type=pidget&amp;guid=4dLx_5fLkFbF&amp;tv=2019040401&amp;event=init&amp;sub=www&amp;button_count=0&amp;follow_count=0&amp;pin_count=0&amp;profile_count=0&amp;board_count=0&amp;section_count=0&amp;lang=en&amp;nvl=en-US&amp;via=https%3A%2F%2Fwww.ikea.co.id%2Fin%2Fsearch%2F%3Fq%3Dmeja&amp;callback=PIN_1579847255328.f.callback[0]" type="text/javascript"></script><iframe id="_hjRemoteVarsFrame" name="_hjRemoteVarsFrame" src="https://vars.hotjar.com/box-b736908ce6b0e933fad3a2e45df61b38.html" style="display: none !important; width: 1px !important; height: 1px !important; opacity: 0 !important; pointer-events: none !important;" title="_hjRemoteVarsFrame"></iframe><iframe height="1" src="//tags.tiqcdn.com/utag/xaxis/-ikea/prod/mobile.html?order_id=&amp;order_total=0.00&amp;order_subtotal=0.00&amp;lbData_MP1=&amp;refAction=direct&amp;order_currency=USD&amp;xaxis_title=Hasil%20Pencarian%20untuk%20meja%20%7C%20IKEA%20Indonesia&amp;xaxis_hash=&amp;xaxis_domain=www.ikea.co.id&amp;xaxis_pathname=%2Fin%2Fsearch%2F&amp;xaxis_url=https%3A%2F%2Fwww.ikea.co.id%2Fin%2Fsearch%2F%3Fq%3Dmeja&amp;xaxis_referrer=" style="display:none" width="1"></iframe><div><div id="_hj_feedback_container"> <style type="text/css">                    /*reset css*/                    ._hj-f5b2a1eb-9b07_widget, ._hj-f5b2a1eb-9b07_widget * {                        line-height: normal;                        font-family: Arial, sans-serif, Tahoma !important;                        text-transform: initial !important;                        letter-spacing: normal !important;                    }                    ._hj-f5b2a1eb-9b07_widget, ._hj-f5b2a1eb-9b07_widget div {                        height: auto;                    }                    ._hj-f5b2a1eb-9b07_widget div,                    ._hj-f5b2a1eb-9b07_widget span,                    ._hj-f5b2a1eb-9b07_widget p,                    ._hj-f5b2a1eb-9b07_widget a,                    ._hj-f5b2a1eb-9b07_widget button {                        font-weight: normal !important;                    }                    ._hj-f5b2a1eb-9b07_widget div,                    ._hj-f5b2a1eb-9b07_widget span,                    ._hj-f5b2a1eb-9b07_widget p,                    ._hj-f5b2a1eb-9b07_widget a,                    ._hj-f5b2a1eb-9b07_widget img,                    ._hj-f5b2a1eb-9b07_widget strong,                    ._hj-f5b2a1eb-9b07_widget form,                    ._hj-f5b2a1eb-9b07_widget label {                        border: 0;                        outline: 0;                        font-size: 100%;                        vertical-align: baseline;                        background: transparent;                        margin: 0;                        padding: 0;                        float: none !important;                    }                    ._hj-f5b2a1eb-9b07_widget span {color:inherit}                    ._hj-f5b2a1eb-9b07_widget ol,                    ._hj-f5b2a1eb-9b07_widget ul,                    ._hj-f5b2a1eb-9b07_widget li {                        list-style-type:none !important;                        margin: 0 !important;                        padding: 0 !important;                     }                    ._hj-f5b2a1eb-9b07_widget li:before,                    ._hj-f5b2a1eb-9b07_widget li:after {                        content: none !important;                    }                    ._hj-f5b2a1eb-9b07_widget hr {                        display:block;                        height:1px;                        border:0;                   ...

# %%
#setelah data htmlnya sudah didapatkan lalu dilakukan pencarian
#tag div beserta class nya kemudian diambil data gambar, produk
#nama produk, dan harga produk
#for melakukan perulangan untuk mengambil semua data yang ada class ta-productnya
content = driver.page_source
soup = BeautifulSoup(content)
for link in soup.find_all('div', class_="card px-4"):
    print(link)
# Out:
# <div class="card px-4" id="card_334126">
# <div class="card-header">
# <a href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/barsviken-meja-dengan-daun-meja-lipat-hitam-art-00334126">
# <div class="itemBadges">
# </div>
# <span class="productImg">
# <img alt="BARSVIKEN - Meja dengan daun meja lipat, hitam" class="card-img-top" onerror="this.src='/webroot/img/icons/noImage.png?v=1579530442'" src="https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/689/0368937_PE549760_S3.jpg"/>
# </span>
# </a>
# </div>
# <div class="card-body">
# <div class="itemInfo">
# <input name="productInfo" type="hidden" value='{"name":"BARSVIKEN - Meja dengan daun meja lipat, hitam","brand":"BARSVIKEN","id":"334126","price":"1999000","category":"Furniture\/Dining\/Dining tables\/Tables ","variant":"ART"}'/>
# <a class="itemName" href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/barsviken-meja-dengan-daun-meja-lipat-hitam-art-00334126">
# <h6 class="display-7">BARSVIKEN</h6>
# </a>
# <div class="itemDetails">
# <span class="itemFacts">Meja dengan daun meja lipat, hitam</span>
# </div>
# <div class="itemPriceBox">
# <div class="itemPrice-wrapper">
# <p class="itemNormalPrice display-6">
# <span data-price="1999000">Rp 1.999.000</span>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="card-footer">
# <button class="btn btn-outline-gray-medium mx-auto btn-icon sidenavItem quickLook" data-action="sidenav" data-item="00334126" data-stock="11">
# <span class="icon-quickview"></span>
# <span>Lihat sekilas</span>
# </button>
# </div>
# <div class="card-compare">
# <div class="ml-4 check">
# <label class="checkboxCompare" for="check_334126">
# <input class="listItem" id="check_334126" onchange="Comparator.addItemComparator({&quot;combination_items&quot;:null,&quot;partnumber&quot;:&quot;00334126&quot;,&quot;has_relations&quot;:false,&quot;unit_value&quot;:null,&quot;unit_imperial&quot;:null,&quot;unit_metric&quot;:null,&quot;unit_unit&quot;:null,&quot;valid_design&quot;:&quot;hitam&quot;,&quot;activitystartdate&quot;:null,&quot;activityenddate&quot;:null,&quot;id&quot;:334126,&quot;almcod&quot;:null,&quot;name&quot;:&quot;BARSVIKEN&quot;,&quot;type&quot;:&quot;ART&quot;,&quot;productarea&quot;:811,&quot;requires_assembly&quot;:true,&quot;default_image&quot;:&quot;https:\/\/d2xjmi1k71iy2m.cloudfront.net\/dairyfarm\/id\/images\/689\/0368937_PE549760_S3.jpg&quot;,&quot;designers&quot;:null,&quot;stylegroup&quot;:&quot;Popular Modern&quot;,&quot;efficiency&quot;:null,&quot;price_range&quot;:&quot;Low&quot;,&quot;facts&quot;:&quot;meja dengan daun meja lipat&quot;,&quot;extra_facts&quot;:&quot;meja dengan daun meja lipat, hitam&quot;,&quot;energy_tag&quot;:null,&quot;color&quot;:&quot;hitam&quot;,&quot;size&quot;:null,&quot;search_value&quot;:&quot;'-4':47 '00334126':3B '2':46 '4':13 'akrilik':65C,79C,87C 'anda':10,32 'atas':26 'bagian':25 'barsviken':2B 'bawah':58C,82C 'beech':61C,73C,76C 'bening':66C,80C,88C 'dan':19 'dapat':11,29,43 'daun':6A,17,41,67C 'dengan':5A,40 'dibawah':16 'digunakan':24 'dilipat':30,44 'fibreboard':84C 'h4':59C,69C,83C,90C 'hitam':9 'kaki':56C 'kayu':60C,72C,75C 'kebutuhan':38,55 'kursi':14 'lacquer':64C,78C,86C 'lipat':8A,15 'meja':1C,4A,7A,18,27,36,39,53,68C 'memungkinkan':31,49 'menghemat':20 'menyesuaikan':34,51 'menyimpan':12 'orang':48 'panel':81C 'particleboard':70C 'pewarna':63C,77C,85C 'plastik':91C 'polipropilena':92C 'rangka':57C 'roda':89C 'ruang':21 'saat':22 'sesuai':37,54 'solid':62C 'tidak':23 'ukuran':35,52 'untuk':33,45,50 'veneer':71C,74C 'yang':28,42&quot;,&quot;length_metric&quot;:null,&quot;length_imperial&quot;:null,&quot;width_metric&quot;:&quot;93&quot;,&quot;width_imperial&quot;:&quot;36 5\/8 inci&quot;,&quot;height_metric&quot;:&quot;74&quot;,&quot;height_imperial&quot;:&quot;29 1\/8 inci&quot;,&quot;diameter_metric&quot;:null,&quot;diameter_imperial&quot;:null,&quot;resume_measure_metric&quot;:&quot;45\/90\/135x93 cm&quot;,&quot;resume_measure_imperial&quot;:&quot;17 3\/4\/35 3\/8\/53 1\/8x36 5\/8 inci&quot;,&quot;current_price&quot;:&quot;1999000&quot;,&quot;hbp_price&quot;:null,&quot;original_price&quot;:&quot;1999000&quot;,&quot;offer_price&quot;:null,&quot;family_price&quot;:null,&quot;stock&quot;:11,&quot;bti&quot;:false,&quot;is_new&quot;:false,&quot;top_seller&quot;:null,&quot;sold&quot;:0,&quot;show_in_web&quot;:true,&quot;buy_in_web&quot;:true,&quot;start_sale_date&quot;:&quot;2019-02-01&quot;,&quot;end_sale_date&quot;:null,&quot;start_sale_date_showable&quot;:null,&quot;end_sale_date_showable&quot;:null,&quot;location&quot;:&quot;PICKING&quot;,&quot;salesmethod&quot;:&quot;F&quot;,&quot;formated_location&quot;:{&quot;title&quot;:null,&quot;result&quot;:&quot;&lt;span&gt;Available online and Order from I-Counter&lt;\/span&gt;&quot;},&quot;full_category&quot;:&quot;Furniture\/Dining\/Dining tables\/Tables &quot;,&quot;url&quot;:&quot;\/in\/produk\/ruang-makan\/meja-ruang-makan\/meja-makan\/barsviken-meja-dengan-daun-meja-lipat-hitam-art-00334126&quot;},id,{&quot;position&quot;:1,&quot;currency&quot;:&quot;Rp&quot;,&quot;dec_number&quot;:2,&quot;dec_separator&quot;:&quot;,&quot;,&quot;thousand_separator&quot;:&quot;.&quot;})" type="checkbox" value=""/>
# <span class="checkmark"></span>
# <span class="compareText">Bandingkan</span>
# </label>
# </div>
# </div>
# </div>
# <div class="card px-4" id="card_50452607">
# <div class="card-header">
# <a href="/in/produk/ruang-keluarga/meja-ruang-tamu/meja-tamu-dan-meja-samping/nyboda-meja-tamu-dg-daun-meja-dpt-dibalik-abu-abu-tua-hitam-art-50452607">
# <div class="itemBadges">
# <div class="badge-new-circular" id="new"><span>BARU</span></div>
# </div>
# <span class="productImg">
# <img alt="NYBODA - Meja tamu dg daun meja dpt dibalik, abu-abu tua kesan beton/hitam" class="card-img-top" onerror="this.src='/webroot/img/icons/noImage.png?v=1579530442'" src="https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/665/0766504_PE753800_S3.jpg"/>
# </span>
# </a>
# </div>
# <div class="card-body">
# <div class="itemInfo">
# <input name="productInfo" type="hidden" value='{"name":"NYBODA - Meja tamu dg daun meja dpt dibalik, abu-abu tua kesan beton\/hitam","brand":"NYBODA","id":"50452607","price":"1499000","category":"Furniture\/Hospitality \/Furniture\/Sofa tables","variant":"ART"}'/>
# <a class="itemName" href="/in/produk/ruang-keluarga/meja-ruang-tamu/meja-tamu-dan-meja-samping/nyboda-meja-tamu-dg-daun-meja-dpt-dibalik-abu-abu-tua-hitam-art-50452607">
# <h6 class="display-7">NYBODA</h6>
# </a>
# <div class="itemDetails">
# <span class="itemFacts">Meja tamu dg daun meja dpt dibalik, abu-abu tua kesan beton/hitam</span>
# </div>
# <div class="itemPriceBox">
# <div class="itemPrice-wrapper">
# <p class="itemNormalPrice display-6">
# <span data-price="1499000">Rp 1.499.000</span>
# </p>
# </div>
# </div>
# </div>
# <p class="itemMore mt-2 pb-1">Tersedia lebih banyak pilihan</p>
# </div>
# <div class="card-footer">
# <button class="btn btn-outline-gray-medium mx-auto btn-icon sidenavItem quickLook" data-action="sidenav" data-item="50452607" data-stock="4">
# <span class="icon-quickview"></span>
# <span>Lihat sekilas</span>
# </button>
# </div>
# <div class="card-compare">
# <div class="ml-4 check">
# <label class="checkboxCompare" for="check_50452607">
# <input class="listItem" id="check_50452607" onchange="Comparator.addItemComparator({&quot;combination_items&quot;:null,&quot;partnumber&quot;:&quot;50452607&quot;,&quot;has_relations&quot;:true,&quot;unit_value&quot;:null,&quot;unit_imperial&quot;:null,&quot;unit_metric&quot;:null,&quot;unit_unit&quot;:null,&quot;valid_design&quot;:&quot;abu-abu tua kesan beton\/hitam&quot;,&quot;activitystartdate&quot;:null,&quot;activityenddate&quot;:null,&quot;id&quot;:50452607,&quot;almcod&quot;:null,&quot;name&quot;:&quot;NYBODA&quot;,&quot;type&quot;:&quot;ART&quot;,&quot;productarea&quot;:121,&quot;requires_assembly&quot;:true,&quot;default_image&quot;:&quot;https:\/\/d2xjmi1k71iy2m.cloudfront.net\/dairyfarm\/id\/images\/665\/0766504_PE753800_S3.jpg&quot;,&quot;designers&quot;:&quot;Ehl\u00e9n Johansson&quot;,&quot;stylegroup&quot;:&quot;IKEA Basic Modern&quot;,&quot;efficiency&quot;:null,&quot;price_range&quot;:&quot;Medium&quot;,&quot;facts&quot;:&quot;meja tamu dg daun meja dpt dibalik&quot;,&quot;extra_facts&quot;:&quot;meja tamu dg daun meja dpt dibalik, abu-abu tua kesan beton\/hitam&quot;,&quot;energy_tag&quot;:null,&quot;color&quot;:&quot;abu-abu tua-hitam&quot;,&quot;size&quot;:null,&quot;search_value&quot;:&quot;'100':119C '50452607':4B 'abu':13,14 'abu-abu':12 'anda':25,37,52 'atas':102C,111C 'atau':30 'baja':106C 'banyak':81 'bawah':87,104C 'bentuk':70 'berbeda':36 'berdampingan':57 'bersama':32 'bersama-sama':31 'bersih':73,99 'besar':64 'control':94 'dalam':19,34 'dan':50,69,74,92 'dapat':26,38,47,53 'daun':8A,41 'dengan':67,80 'dg':7A 'di':86 'dibalik':11A,48 'didaur':120C 'didesain':22 'dikombinasikan':79 'dilapisi':107C 'dpt':10A 'dua':55 'epoksi':109C 'fibreboard':122C 'fleksibel':23 'foil':124C 'garis':72 'gaya':82 'h4':105C,112C 'hitam':17,49 'karena':45 'kebutuhan':44 'kertas':115C,123C 'kombinasi':35 'koran':91 'krem':51 'lebah':118C 'lebih':63 'meja':1C,5A,9A,18,42,56,61,77,88,98 'meletakkan':54 'membuat':76 'memilih':39 'mendapat':59 'menggunakannya':27 'menyimpan':90 'misalnya':95 'mudah':78 'nyboda':3B,21 'panel':100C 'particleboard':113C 'pengisian':114C 'perabot':83 'permukaan':60,97 'plastik':126C 'poliester':110C 'rak':85 'rangka':101C,103C 'remote':93 'sama':33 'sarang':117C 'secara':28 'sederhana':75 'sehingga':24,96 'serbuk':108C 'seri':20 'sesuai':43,66 'sisinya':46 'sofa':2C,71 'struktur':116C 'tamu':6A 'tepi':125C 'terdapat':84 'terpisah':29 'tua':16 'tua-hitam':15 'ukuran':68 'ulang':121C 'untuk':58,89 'warna':40 'yang':62,65&quot;,&quot;length_metric&quot;:null,&quot;length_imperial&quot;:null,&quot;width_metric&quot;:&quot;40&quot;,&quot;width_imperial&quot;:&quot;15 3\/4 inci&quot;,&quot;height_metric&quot;:&quot;40&quot;,&quot;height_imperial&quot;:&quot;15 3\/4 inci&quot;,&quot;diameter_metric&quot;:null,&quot;diameter_imperial&quot;:null,&quot;resume_measure_metric&quot;:&quot;120x40x40 cm&quot;,&quot;resume_measure_imperial&quot;:&quot;47 1\/4x15 3\/4x15 3\/4 inci&quot;,&quot;current_price&quot;:&quot;1499000&quot;,&quot;hbp_price&quot;:null,&quot;original_price&quot;:&quot;1499000&quot;,&quot;offer_price&quot;:null,&quot;family_price&quot;:null,&quot;stock&quot;:4,&quot;bti&quot;:false,&quot;is_new&quot;:true,&quot;top_seller&quot;:null,&quot;sold&quot;:0,&quot;show_in_web&quot;:true,&quot;buy_in_web&quot;:true,&quot;start_sale_date&quot;:&quot;2020-02-01&quot;,&quot;end_sale_date&quot;:null,&quot;start_sale_date_showable&quot;:&quot;2020-01-08&quot;,&quot;end_sale_date_showable&quot;:null,&quot;location&quot;:&quot;PICKING&quot;,&quot;salesmethod&quot;:&quot;F&quot;,&quot;formated_location&quot;:{&quot;title&quot;:null,&quot;result&quot;:&quot;&lt;span&gt;Available online and Order from I-Counter&lt;\/span&gt;&quot;},&quot;full_category&quot;:&quot;Furniture\/Hospitality \/Furniture\/Sofa tables&quot;,&quot;url&quot;:&quot;\/in\/produk\/ruang-keluarga\/meja-ruang-tamu\/meja-tamu-dan-meja-samping\/nyboda-meja-tamu-dg-daun-meja-dpt-dibalik-abu-abu-tua-hitam-art-50452607&quot;},id,{&quot;positi ...
# <span class="checkmark"></span>
# <span class="compareText">Bandingkan</span>
# </label>
# </div>
# </div>
# </div>
# <div class="card px-4" id="card_40452622">
# <div class="card-header">
# <a href="/in/produk/ruang-keluarga/meja-ruang-tamu/meja-tamu-dan-meja-samping/nyboda-meja-tamu-dg-daun-meja-dpt-dibalik-putih-abu-abu-muda-art-40452622">
# <div class="itemBadges">
# <div class="badge-new-circular" id="new"><span>BARU</span></div>
# </div>
# <span class="productImg">
# <img alt="NYBODA - Meja tamu dg daun meja dpt dibalik, abu-abu muda kesan beton/putih" class="card-img-top" onerror="this.src='/webroot/img/icons/noImage.png?v=1579530442'" src="https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/665/0766507_PE753803_S3.jpg"/>
# </span>
# </a>
# </div>
# <div class="card-body">
# <div class="itemInfo">
# <input name="productInfo" type="hidden" value='{"name":"NYBODA - Meja tamu dg daun meja dpt dibalik, abu-abu muda kesan beton\/putih","brand":"NYBODA","id":"40452622","price":"1499000","category":"Furniture\/Hospitality \/Furniture\/Sofa tables","variant":"ART"}'/>
# <a class="itemName" href="/in/produk/ruang-keluarga/meja-ruang-tamu/meja-tamu-dan-meja-samping/nyboda-meja-tamu-dg-daun-meja-dpt-dibalik-putih-abu-abu-muda-art-40452622">
# <h6 class="display-7">NYBODA</h6>
# </a>
# <div class="itemDetails">
# <span class="itemFacts">Meja tamu dg daun meja dpt dibalik, abu-abu muda kesan beton/putih</span>
# </div>
# <div class="itemPriceBox">
# <div class="itemPrice-wrapper">
# <p class="itemNormalPrice display-6">
# <span data-price="1499000">Rp 1.499.000</span>
# </p>
# </div>
# </div>
# </div>
# <p class="itemMore mt-2 pb-1">Tersedia lebih banyak pilihan</p>
# </div>
# <div class="card-footer">
# <button class="btn btn-outline-gray-medium mx-auto btn-icon sidenavItem quickLook" data-action="sidenav" data-item="40452622" data-stock="2">
# <span class="icon-quickview"></span>
# <span>Lihat sekilas</span>
# </button>
# </div>
# <div class="card-compare">
# <div class="ml-4 check">
# <label class="checkboxCompare" for="check_40452622">
# <input class="listItem" id="check_40452622" onchange="Comparator.addItemComparator({&quot;combination_items&quot;:null,&quot;partnumber&quot;:&quot;40452622&quot;,&quot;has_relations&quot;:true,&quot;unit_value&quot;:null,&quot;unit_imperial&quot;:null,&quot;unit_metric&quot;:null,&quot;unit_unit&quot;:null,&quot;valid_design&quot;:&quot;abu-abu muda kesan beton\/putih&quot;,&quot;activitystartdate&quot;:null,&quot;activityenddate&quot;:null,&quot;id&quot;:40452622,&quot;almcod&quot;:null,&quot;name&quot;:&quot;NYBODA&quot;,&quot;type&quot;:&quot;ART&quot;,&quot;productarea&quot;:121,&quot;requires_assembly&quot;:true,&quot;default_image&quot;:&quot;https:\/\/d2xjmi1k71iy2m.cloudfront.net\/dairyfarm\/id\/images\/665\/0766507_PE753803_S3.jpg&quot;,&quot;designers&quot;:&quot;Ehl\u00e9n Johansson&quot;,&quot;stylegroup&quot;:&quot;IKEA Basic Modern&quot;,&quot;efficiency&quot;:null,&quot;price_range&quot;:&quot;Medium&quot;,&quot;facts&quot;:&quot;meja tamu dg daun meja dpt dibalik&quot;,&quot;extra_facts&quot;:&quot;meja tamu dg daun meja dpt dibalik, abu-abu muda kesan beton\/putih&quot;,&quot;energy_tag&quot;:null,&quot;color&quot;:&quot;putih-abu-abu muda&quot;,&quot;size&quot;:null,&quot;search_value&quot;:&quot;'100':118C '40452622':4B 'abu':14,15 'anda':17,37,59 'atas':101C,110C 'atau':64 'baja':105C 'banyak':80 'bawah':86,103C 'bentuk':35 'berbeda':70 'berdampingan':22 'bersama':66 'bersama-sama':65 'bersih':72,98 'besar':29 'control':93 'dalam':53,68 'dan':34,50,73,91 'dapat':18,38,47,60 'daun':8A,41 'dengan':32,79 'dg':7A 'di':85 'dibalik':11A,48 'didaur':119C 'didesain':56 'dikombinasikan':78 'dilapisi':106C 'dpt':10A 'dua':20 'epoksi':108C 'fibreboard':121C 'fleksibel':57 'foil':123C 'garis':71 'gaya':81 'h4':104C,111C 'hitam':49 'karena':45 'kebutuhan':44 'kertas':114C,122C 'kombinasi':69 'koran':90 'krem':51 'lebah':117C 'lebih':28 'meja':1C,5A,9A,21,26,42,52,76,87,97 'meletakkan':19 'membuat':75 'memilih':39 'mendapat':24 'menggunakannya':61 'menyimpan':89 'misalnya':94 'muda':16 'mudah':77 'nyboda':3B,55 'panel':99C 'particleboard':112C 'pengisian':113C 'perabot':82 'permukaan':25,96 'plastik':125C 'poliester':109C 'putih':13 'putih-abu-abu':12 'rak':84 'rangka':100C,102C 'remote':92 'sama':67 'sarang':116C 'secara':62 'sederhana':74 'sehingga':58,95 'serbuk':107C 'seri':54 'sesuai':31,43 'sisinya':46 'sofa':2C,36 'struktur':115C 'tamu':6A 'tepi':124C 'terdapat':83 'terpisah':63 'ukuran':33 'ulang':120C 'untuk':23,88 'warna':40 'yang':27,30&quot;,&quot;length_metric&quot;:null,&quot;length_imperial&quot;:null,&quot;width_metric&quot;:&quot;40&quot;,&quot;width_imperial&quot;:&quot;15 3\/4 inci&quot;,&quot;height_metric&quot;:&quot;40&quot;,&quot;height_imperial&quot;:&quot;15 3\/4 inci&quot;,&quot;diameter_metric&quot;:null,&quot;diameter_imperial&quot;:null,&quot;resume_measure_metric&quot;:&quot;120x40x40 cm&quot;,&quot;resume_measure_imperial&quot;:&quot;47 1\/4x15 3\/4x15 3\/4 inci&quot;,&quot;current_price&quot;:&quot;1499000&quot;,&quot;hbp_price&quot;:null,&quot;original_price&quot;:&quot;1499000&quot;,&quot;offer_price&quot;:null,&quot;family_price&quot;:null,&quot;stock&quot;:2,&quot;bti&quot;:false,&quot;is_new&quot;:true,&quot;top_seller&quot;:null,&quot;sold&quot;:0,&quot;show_in_web&quot;:true,&quot;buy_in_web&quot;:true,&quot;start_sale_date&quot;:&quot;2020-02-01&quot;,&quot;end_sale_date&quot;:null,&quot;start_sale_date_showable&quot;:&quot;2019-12-30&quot;,&quot;end_sale_date_showable&quot;:null,&quot;location&quot;:&quot;PICKING&quot;,&quot;salesmethod&quot;:&quot;F&quot;,&quot;formated_location&quot;:{&quot;title&quot;:null,&quot;result&quot;:&quot;&lt;span&gt;Available online and Order from I-Counter&lt;\/span&gt;&quot;},&quot;full_category&quot;:&quot;Furniture\/Hospitality \/Furniture\/Sofa tables&quot;,&quot;url&quot;:&quot;\/in\/produk\/ruang-keluarga\/meja-ruang-tamu\/meja-tamu-dan-meja-samping\/nyboda-meja-tamu-dg-daun-meja-dpt-dibalik-putih-abu-abu-muda-art-40452622&quot;},id,{&quot;pos ...
# <span class="checkmark"></span>
# <span class="compareText">Bandingkan</span>
# </label>
# </div>
# </div>
# </div>
# <div class="card px-4" id="card_89240780">
# <div class="card-header">
# <a href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/ingatorp-ingatorp-meja-dan-4-kursi-hitam-spr-89240780">
# <div class="itemBadges">
# </div>
# <span class="productImg">
# <img alt="INGATORP/INGATORP - Meja dan 4 kursi, hitam" class="card-img-top" onerror="this.src='/webroot/img/icons/noImage.png?v=1579530442'" src="https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/377/0737793_PE741254_S3.jpg"/>
# </span>
# </a>
# </div>
# <div class="card-body">
# <div class="itemInfo">
# <input name="productInfo" type="hidden" value='{"name":"INGATORP\/INGATORP - Meja dan 4 kursi, hitam","brand":"INGATORP\/INGATORP","id":"89240780","price":"13179000","category":"Furniture\/Dining\/Dining tables\/Tables ","variant":"SPR"}'/>
# <a class="itemName" href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/ingatorp-ingatorp-meja-dan-4-kursi-hitam-spr-89240780">
# <h6 class="display-7">INGATORP/INGATORP</h6>
# </a>
# <div class="itemDetails">
# <span class="itemFacts">Meja dan 4 kursi, hitam</span>
# </div>
# <div class="itemPriceBox">
# <div class="itemPrice-wrapper">
# <p class="itemNormalPrice display-6">
# <span data-price="13179000">Rp 13.179.000</span>
# </p>
# </div>
# </div>
# </div>
# <p class="itemMore mt-2 pb-1">Tersedia lebih banyak pilihan</p>
# </div>
# <div class="card-footer">
# <button class="btn btn-outline-gray-medium mx-auto btn-icon sidenavItem quickLook" data-action="sidenav" data-item="89240780" data-stock="2">
# <span class="icon-quickview"></span>
# <span>Lihat sekilas</span>
# </button>
# </div>
# <div class="card-compare">
# <div class="ml-4 check">
# <label class="checkboxCompare" for="check_89240780">
# <input class="listItem" id="check_89240780" onchange="Comparator.addItemComparator({&quot;combination_items&quot;:null,&quot;partnumber&quot;:&quot;89240780&quot;,&quot;has_relations&quot;:true,&quot;unit_value&quot;:null,&quot;unit_imperial&quot;:null,&quot;unit_metric&quot;:null,&quot;unit_unit&quot;:null,&quot;valid_design&quot;:&quot;hitam&quot;,&quot;activitystartdate&quot;:null,&quot;activityenddate&quot;:null,&quot;id&quot;:89240780,&quot;almcod&quot;:null,&quot;name&quot;:&quot;INGATORP\/INGATORP&quot;,&quot;type&quot;:&quot;SPR&quot;,&quot;productarea&quot;:811,&quot;requires_assembly&quot;:true,&quot;default_image&quot;:&quot;https:\/\/d2xjmi1k71iy2m.cloudfront.net\/dairyfarm\/id\/images\/377\/0737793_PE741254_S3.jpg&quot;,&quot;designers&quot;:&quot;Carina Bengs\/Ebba Strandmark&quot;,&quot;stylegroup&quot;:null,&quot;efficiency&quot;:null,&quot;price_range&quot;:null,&quot;facts&quot;:&quot;meja dan 4 kursi&quot;,&quot;extra_facts&quot;:&quot;meja dan 4 kursi, hitam&quot;,&quot;energy_tag&quot;:null,&quot;color&quot;:&quot;hitam&quot;,&quot;size&quot;:null,&quot;search_value&quot;:&quot;'-6':28 '1':10,22 '25':252C '35':230C,239C '4':7A,27 '75':250C '89240780':4B 'abs':171C 'acara':82 'akan':64 'akrilik':165C,174C,187C,199C,207C,219C 'anda':67,111,122 'ash':178C,191C 'atas':60 'bagian':59,192C 'banyak':74 'bawah':58,132 'bening':175C,188C,200C 'bentuk':144 'berbentuk':213C,217C 'berlengan':92,105 'bersandar':113 'birch':162C,196C,204C 'bisa':118 'busa':224C,228C,233C,237C 'cat':164C,206C,218C 'cocok':80 'cukup':106,115 'dan':6A,71,89,99,114,151 'dapat':19,55,129,135 'daun':11,23,45,52,166C,179C 'dengan':21,96,147 'di':49,57 'didorong':130 'diduduki':95 'digunakan':140 'diletakkan':48 'dingin':229C,238C 'dipanjangkan':43 'diperpanjang':20 'disekitar':78 'disimpan':56 'ditenun':246C 'duduk':119,221C 'dudukan':100 'ekstra':102 'elastis':226C,235C 'fibreboard':223C 'h4':160C,168C,181C,194C,202C,209C,222C,249C 'hitam':9 'ingatorp':2B,3B,150 'inginkan':123 'isi':242C 'kaki':62,148,157C 'karena':44,87 'katun':251C 'kayu':161C,177C,190C,195C,203C 'ke':124,131 'kebutuhan':36 'keluar':70 'ketinggian':90 'kg':231C,240C 'kursi':8A,77,91,104,128,153 'lacquer':173C,186C,198C 'lainnya':193C 'lama':86 'lapisan':210C,214C 'lebih':73 'm3':232C,241C 'makan':17,83,127 'malam':84 'meja':1C,5A,12,16,24,34,41,46,51,53,61,63,69,79,125,133,149,167C 'memberikan':152 'membuat':72 'memiliki':143 'memungkinkan':30 'menarik':68 'menghemat':136 'mengikuti':65 'menopang':109 'menyesuaikan':32 'modern':154 'nyaman':93 'orang':29 'panjang':88,107 'papan':211C,215C 'particleboard':169C,182C 'pendek':116 'penyambung':47 'perpanjangan':180C 'pewarna':172C,185C 'plastik':170C,184C 'poliester':243C,253C 'polipropilena':244C 'poliuretana':225C,234C 'punggung':98,110 'punggungnya':142 'rangka':201C 'rel':158C 'ruang':75,137 'saat':40,66,112,126,138 'sama':146 'sambungan':39 'samping':159C 'sandaran':97,141,208C 'sarung':247C,248C 'sedekat':120 'sehingga':134 'sentuhan':155 'serat':212C,216C 'sesuai':35 'solid':163C,197C,205C 'sudah':14 'tambahan':13,25,54 'tebal':103 'tempat':220C 'tepi':183C 'terdapat':38 'termasuk':15 'tidak':37,42,139,245C 'tinggi':227C,236C 'tradisional':156 'ujung':50 'ukuran':33 'untuk':26,31,76,81,94,108,117 'veneer':176C,189C 'yang':18,85,101,121,145&quot;,&quot;length_metric&quot;:null,&quot;length_imperial&quot;:null,&quot;width_metric&quot;:&quot;87&quot;,&quot;width_imperial&quot;:&quot;34 1\/4 inci&quot;,&quot;height_metric&quot;:&quot;74&quot;,&quot;height_imperial&quot;:&quot;29 1\/8 inci&quot;,&quot;diameter_metric&quot;:null,&quot;diameter_imperial&quot;:null,&quot;resume_measure_metric&quot;:&quot;155 cm&quot;,&quot;resume_measure_imperial&quot;:&quot;61 inci&quot;,&quot;current_price&quot;:&quot;13179000&quot;,&quot;hbp_price&quot;:&quot;13179000&quot;,&quot;original_price&quot;:&quot;13179000&quot;,&quot;offer_price&quot;:&quot;13179000&quot;,&quot;family_price&quot;:null,&quot;stock&quot;:2,&quot;bti&quot;:false,&quot; ...
# <span class="checkmark"></span>
# <span class="compareText">Bandingkan</span>
# </label>
# </div>
# </div>
# </div>
# <div class="card px-4" id="card_60423110">
# <div class="card-header">
# <a href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/ingatorp-meja-dengan-daun-meja-lipat-putih-art-60423110">
# <div class="itemBadges">
# </div>
# <span class="productImg">
# <img alt="INGATORP - Meja dengan daun meja lipat, putih" class="card-img-top" onerror="this.src='/webroot/img/icons/noImage.png?v=1579530442'" src="https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/492/0449209_PE598742_S3.jpg"/>
# </span>
# </a>
# </div>
# <div class="card-body">
# <div class="itemInfo">
# <input name="productInfo" type="hidden" value='{"name":"INGATORP - Meja dengan daun meja lipat, putih","brand":"INGATORP","id":"60423110","price":"2999000","category":"Furniture\/Dining\/Dining tables\/Tables ","variant":"ART"}'/>
# <a class="itemName" href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/ingatorp-meja-dengan-daun-meja-lipat-putih-art-60423110">
# <h6 class="display-7">INGATORP</h6>
# </a>
# <div class="itemDetails">
# <span class="itemFacts">Meja dengan daun meja lipat, putih</span>
# </div>
# <div class="itemPriceBox">
# <div class="itemPrice-wrapper">
# <p class="itemNormalPrice display-6">
# <span data-price="2999000">Rp 2.999.000</span>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="card-footer">
# <button class="btn btn-outline-gray-medium mx-auto btn-icon sidenavItem quickLook" data-action="sidenav" data-item="60423110" data-stock="5">
# <span class="icon-quickview"></span>
# <span>Lihat sekilas</span>
# </button>
# </div>
# <div class="card-compare">
# <div class="ml-4 check">
# <label class="checkboxCompare" for="check_60423110">
# <input class="listItem" id="check_60423110" onchange="Comparator.addItemComparator({&quot;combination_items&quot;:null,&quot;partnumber&quot;:&quot;60423110&quot;,&quot;has_relations&quot;:false,&quot;unit_value&quot;:null,&quot;unit_imperial&quot;:null,&quot;unit_metric&quot;:null,&quot;unit_unit&quot;:null,&quot;valid_design&quot;:&quot;putih&quot;,&quot;activitystartdate&quot;:null,&quot;activityenddate&quot;:null,&quot;id&quot;:60423110,&quot;almcod&quot;:null,&quot;name&quot;:&quot;INGATORP&quot;,&quot;type&quot;:&quot;ART&quot;,&quot;productarea&quot;:811,&quot;requires_assembly&quot;:true,&quot;default_image&quot;:&quot;https:\/\/d2xjmi1k71iy2m.cloudfront.net\/dairyfarm\/id\/images\/492\/0449209_PE598742_S3.jpg&quot;,&quot;designers&quot;:&quot;Carina Bengs&quot;,&quot;stylegroup&quot;:&quot;Popular Traditional&quot;,&quot;efficiency&quot;:null,&quot;price_range&quot;:&quot;Medium&quot;,&quot;facts&quot;:&quot;meja dengan daun meja lipat&quot;,&quot;extra_facts&quot;:&quot;meja dengan daun meja lipat, putih&quot;,&quot;energy_tag&quot;:null,&quot;color&quot;:&quot;putih&quot;,&quot;size&quot;:null,&quot;search_value&quot;:&quot;'-4':34 '2':33 '60423110':3B 'abs':99C 'akrilik':89C,97C,108C,116C,123C 'alami':74 'anda':65 'atau':22 'bagian':13 'bahan':73 'baik':77 'bawah':14,82C 'beech':86C 'belakang':127C 'berbentuk':106C 'bermotif':137C 'bertahun':68 'bertahun-tahun':67 'birch':113C 'cat':88C,96C,107C,115C,122C 'dalam':51 'dan':55 'dapat':30 'dasar':133C 'daun':6A,15,28,90C,92C 'daya':53 'dekat':24 'dengan':5A,27,47,79 'depan':118C 'di':12,63 'dilipat':31 'diuji':46 'fibreboard':121C,136C 'h4':84C,94C,102C,111C,120C,129C,135C 'hari':62 'ingatorp':2B 'ini':44 'kaki':83C 'kami':50 'kayu':70,85C,112C,130C 'keamanan':56 'kebutuhan':42 'ketat':49 'laci':10,119C,126C,128C,134C 'lapisan':103C 'lilin':23 'lipat':8A,93C 'makan':20 'meja':1C,4A,7A,16,25,26,40,43,91C 'memungkinkan':36 'menahan':58 'menyesuaikan':38 'menyimpan':18 'muka':117C 'orang':35 'padat':72 'papan':104C 'particleboard':95C 'penggunaan':59 'penyokong':110C 'peralatan':19 'pinus':71,131C 'plastik':98C 'praktis':11 'putih':9 'rel':81C,100C,109C 'rumah':64 'samping':101C 'sehari':61 'sehari-hari':60 'seiring':78 'selama':66 'semakin':76 'serat':105C 'serbet':21 'sesuai':41 'sisi':124C 'solid':87C,114C,132C 'stabilitas':52 'standar':48 'tahan':54 'tahun':69 'telah':45 'tepi':125C 'ukuran':39 'untuk':17,32,37,57 'waktu':80 'yang':29,75&quot;,&quot;length_metric&quot;:null,&quot;length_imperial&quot;:null,&quot;width_metric&quot;:&quot;78&quot;,&quot;width_imperial&quot;:&quot;30 3\/4 inci&quot;,&quot;height_metric&quot;:&quot;75&quot;,&quot;height_imperial&quot;:&quot;29 1\/2 inci&quot;,&quot;diameter_metric&quot;:null,&quot;diameter_imperial&quot;:null,&quot;resume_measure_metric&quot;:&quot;65\/123x78 cm&quot;,&quot;resume_measure_imperial&quot;:&quot;25 5\/8\/48 3\/8x30 3\/4 inci&quot;,&quot;current_price&quot;:&quot;2999000&quot;,&quot;hbp_price&quot;:null,&quot;original_price&quot;:&quot;2999000&quot;,&quot;offer_price&quot;:null,&quot;family_price&quot;:null,&quot;stock&quot;:5,&quot;bti&quot;:false,&quot;is_new&quot;:false,&quot;top_seller&quot;:null,&quot;sold&quot;:0,&quot;show_in_web&quot;:true,&quot;buy_in_web&quot;:true,&quot;start_sale_date&quot;:&quot;2018-10-01&quot;,&quot;end_sale_date&quot;:null,&quot;start_sale_date_showable&quot;:null,&quot;end_sale_date_showable&quot;:null,&quot;location&quot;:&quot;PICKING&quot;,&quot;salesmethod&quot;:&quot;F&quot;,&quot;formated_location&quot;:{&quot;title&quot;:null,&quot;result&quot;:&quot;&lt;span&gt;Available online and Order from I-Counter&lt;\/span&gt;&quot;},&quot;full_category&quot;:&quot;Furniture\/Dining\/Dining tables\/Tables &quot;,&quot;url&quot;:&quot;\/in\/produk\/ruang-makan\/meja-ruang-makan\/meja-makan\/ingatorp-meja-dengan-daun-meja-lipat-putih-art-60423110&quot;},id,{&quot;position&quot;:1,&quot;currency&quot;:&quot;Rp&quot;,&quot;dec_number&quot;:2,&quot;dec_separator&quot;:&quot;,&quot;, ...
# <span class="checkmark"></span>
# <span class="compareText">Bandingkan</span>
# </label>
# </div>
# </div>
# </div>
# <div class="card px-4" id="card_70452625">
# <div class="card-header">
# <a href="/in/produk/ruang-keluarga/meja-ruang-tamu/meja-tamu-dan-meja-samping/nyboda-meja-tamu-dg-daun-meja-dpt-dibalik-abu-abu-tua-hitam-art-70452625">
# <div class="itemBadges">
# <div class="badge-new-circular" id="new"><span>BARU</span></div>
# </div>
# <span class="productImg">
# <img alt="NYBODA - Meja tamu dg daun meja dpt dibalik, abu-abu tua kesan beton/hitam" class="card-img-top" onerror="this.src='/webroot/img/icons/noImage.png?v=1579530442'" src="https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/665/0766508_PE753804_S3.jpg"/>
# </span>
# </a>
# </div>
# <div class="card-body">
# <div class="itemInfo">
# <input name="productInfo" type="hidden" value='{"name":"NYBODA - Meja tamu dg daun meja dpt dibalik, abu-abu tua kesan beton\/hitam","brand":"NYBODA","id":"70452625","price":"899000","category":"Furniture\/Hospitality \/Furniture\/Sofa tables","variant":"ART"}'/>
# <a class="itemName" href="/in/produk/ruang-keluarga/meja-ruang-tamu/meja-tamu-dan-meja-samping/nyboda-meja-tamu-dg-daun-meja-dpt-dibalik-abu-abu-tua-hitam-art-70452625">
# <h6 class="display-7">NYBODA</h6>
# </a>
# <div class="itemDetails">
# <span class="itemFacts">Meja tamu dg daun meja dpt dibalik, abu-abu tua kesan beton/hitam</span>
# </div>
# <div class="itemPriceBox">
# <div class="itemPrice-wrapper">
# <p class="itemNormalPrice display-6">
# <span data-price="899000">Rp 899.000</span>
# </p>
# </div>
# </div>
# </div>
# <p class="itemMore mt-2 pb-1">Tersedia lebih banyak pilihan</p>
# </div>
# <div class="card-footer">
# <button class="btn btn-outline-gray-medium mx-auto btn-icon sidenavItem quickLook" data-action="sidenav" data-item="70452625" data-stock="3">
# <span class="icon-quickview"></span>
# <span>Lihat sekilas</span>
# </button>
# </div>
# <div class="card-compare">
# <div class="ml-4 check">
# <label class="checkboxCompare" for="check_70452625">
# <input class="listItem" id="check_70452625" onchange="Comparator.addItemComparator({&quot;combination_items&quot;:null,&quot;partnumber&quot;:&quot;70452625&quot;,&quot;has_relations&quot;:true,&quot;unit_value&quot;:null,&quot;unit_imperial&quot;:null,&quot;unit_metric&quot;:null,&quot;unit_unit&quot;:null,&quot;valid_design&quot;:&quot;abu-abu tua kesan beton\/hitam&quot;,&quot;activitystartdate&quot;:null,&quot;activityenddate&quot;:null,&quot;id&quot;:70452625,&quot;almcod&quot;:null,&quot;name&quot;:&quot;NYBODA&quot;,&quot;type&quot;:&quot;ART&quot;,&quot;productarea&quot;:121,&quot;requires_assembly&quot;:true,&quot;default_image&quot;:&quot;https:\/\/d2xjmi1k71iy2m.cloudfront.net\/dairyfarm\/id\/images\/665\/0766508_PE753804_S3.jpg&quot;,&quot;designers&quot;:&quot;Ehl\u00e9n Johansson&quot;,&quot;stylegroup&quot;:&quot;IKEA Basic Modern&quot;,&quot;efficiency&quot;:null,&quot;price_range&quot;:&quot;Low&quot;,&quot;facts&quot;:&quot;meja tamu dg daun meja dpt dibalik&quot;,&quot;extra_facts&quot;:&quot;meja tamu dg daun meja dpt dibalik, abu-abu tua kesan beton\/hitam&quot;,&quot;energy_tag&quot;:null,&quot;color&quot;:&quot;abu-abu tua-hitam&quot;,&quot;size&quot;:null,&quot;search_value&quot;:&quot;'100':111C '70452625':4B 'abu':13,14 'abu-abu':12 'anda':25,37,52 'atas':96C,103C 'atau':30 'baja':98C 'banyak':90 'bawah':94C 'bentuk':70 'berbeda':36 'berdampingan':57 'bersama':32 'bersama-sama':31 'bersih':82 'besar':64 'dalam':19,34 'dan':50,69,79,83 'dapat':26,38,47,53 'daun':8A,41 'dengan':67,89 'dg':7A 'dibalik':11A,48 'didaur':112C 'didesain':22 'dikombinasikan':88 'dilapisi':99C 'dipindah':74 'dpt':10A 'dua':55 'epoksi':101C 'fibreboard':114C 'fleksibel':23 'foil':116C 'garis':81 'gaya':91 'h4':97C,104C 'hitam':17,49 'karena':45,77 'kebutuhan':44 'kemana':75 'kertas':107C,115C 'kombinasi':35 'krem':51 'lebah':110C 'lebih':63 'meja':1C,5A,9A,18,42,56,61,72,86 'meletakkan':54 'membuat':85 'memilih':39 'mendapat':59 'menggunakannya':27 'mudah':73,87 'nyboda':3B,21 'particleboard':105C 'pengisian':106C 'perabot':92 'permukaan':60 'plastik':118C 'poliester':102C 'rangka':93C,95C 'ringan':78 'saja':76 'sama':33 'sarang':109C 'secara':28 'sederhana':84 'sehingga':24 'serbuk':100C 'seri':20 'sesuai':43,66 'sisinya':46 'sofa':2C,71 'stabil':80 'struktur':108C 'tamu':6A 'tepi':117C 'terpisah':29 'tua':16 'tua-hitam':15 'ukuran':68 'ulang':113C 'untuk':58 'warna':40 'yang':62,65&quot;,&quot;length_metric&quot;:null,&quot;length_imperial&quot;:null,&quot;width_metric&quot;:&quot;60&quot;,&quot;width_imperial&quot;:&quot;23 5\/8 inci&quot;,&quot;height_metric&quot;:&quot;50&quot;,&quot;height_imperial&quot;:&quot;19 5\/8 inci&quot;,&quot;diameter_metric&quot;:null,&quot;diameter_imperial&quot;:null,&quot;resume_measure_metric&quot;:&quot;75x60x50 cm&quot;,&quot;resume_measure_imperial&quot;:&quot;29 1\/2x23 5\/8x19 5\/8 inci&quot;,&quot;current_price&quot;:&quot;899000&quot;,&quot;hbp_price&quot;:null,&quot;original_price&quot;:&quot;899000&quot;,&quot;offer_price&quot;:null,&quot;family_price&quot;:null,&quot;stock&quot;:3,&quot;bti&quot;:false,&quot;is_new&quot;:true,&quot;top_seller&quot;:null,&quot;sold&quot;:0,&quot;show_in_web&quot;:true,&quot;buy_in_web&quot;:true,&quot;start_sale_date&quot;:&quot;2020-02-01&quot;,&quot;end_sale_date&quot;:null,&quot;start_sale_date_showable&quot;:&quot;2020-01-08&quot;,&quot;end_sale_date_showable&quot;:null,&quot;location&quot;:&quot;PICKING&quot;,&quot;salesmethod&quot;:&quot;F&quot;,&quot;formated_location&quot;:{&quot;title&quot;:null,&quot;result&quot;:&quot;&lt;span&gt;Available online and Order from I-Counter&lt;\/span&gt;&quot;},&quot;full_category&quot;:&quot;Furniture\/Hospitality \/Furniture\/Sofa tables&quot;,&quot;url&quot;:&quot;\/in\/produk\/ruang-keluarga\/meja-ruang-tamu\/meja-tamu-dan-meja-samping\/nyboda-meja-tamu-dg-daun-meja-dpt-dibalik-abu-abu-tua-hitam-art-70452625&quot;},id,{&quot;position&quot;:1,&quot;currency&quot;:&quot;Rp&quot;,&quot;dec_number&quot;:2,&q ...
# <span class="checkmark"></span>
# <span class="compareText">Bandingkan</span>
# </label>
# </div>
# </div>
# </div>
# <div class="card px-4" id="card_70452630">
# <div class="card-header">
# <a href="/in/produk/ruang-keluarga/meja-ruang-tamu/meja-tamu-dan-meja-samping/nyboda-meja-tamu-dg-daun-meja-dpt-dibalik-abu-abu-muda-putih-art-70452630">
# <div class="itemBadges">
# <div class="badge-new-circular" id="new"><span>BARU</span></div>
# </div>
# <span class="productImg">
# <img alt="NYBODA - Meja tamu dg daun meja dpt dibalik, abu-abu muda kesan beton/putih" class="card-img-top" onerror="this.src='/webroot/img/icons/noImage.png?v=1579530442'" src="https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/665/0766513_PE753809_S3.jpg"/>
# </span>
# </a>
# </div>
# <div class="card-body">
# <div class="itemInfo">
# <input name="productInfo" type="hidden" value='{"name":"NYBODA - Meja tamu dg daun meja dpt dibalik, abu-abu muda kesan beton\/putih","brand":"NYBODA","id":"70452630","price":"899000","category":"Furniture\/Hospitality \/Furniture\/Sofa tables","variant":"ART"}'/>
# <a class="itemName" href="/in/produk/ruang-keluarga/meja-ruang-tamu/meja-tamu-dan-meja-samping/nyboda-meja-tamu-dg-daun-meja-dpt-dibalik-abu-abu-muda-putih-art-70452630">
# <h6 class="display-7">NYBODA</h6>
# </a>
# <div class="itemDetails">
# <span class="itemFacts">Meja tamu dg daun meja dpt dibalik, abu-abu muda kesan beton/putih</span>
# </div>
# <div class="itemPriceBox">
# <div class="itemPrice-wrapper">
# <p class="itemNormalPrice display-6">
# <span data-price="899000">Rp 899.000</span>
# </p>
# </div>
# </div>
# </div>
# <p class="itemMore mt-2 pb-1">Tersedia lebih banyak pilihan</p>
# </div>
# <div class="card-footer">
# <button class="btn btn-outline-gray-medium mx-auto btn-icon sidenavItem quickLook" data-action="sidenav" data-item="70452630" data-stock="2">
# <span class="icon-quickview"></span>
# <span>Lihat sekilas</span>
# </button>
# </div>
# <div class="card-compare">
# <div class="ml-4 check">
# <label class="checkboxCompare" for="check_70452630">
# <input class="listItem" id="check_70452630" onchange="Comparator.addItemComparator({&quot;combination_items&quot;:null,&quot;partnumber&quot;:&quot;70452630&quot;,&quot;has_relations&quot;:true,&quot;unit_value&quot;:null,&quot;unit_imperial&quot;:null,&quot;unit_metric&quot;:null,&quot;unit_unit&quot;:null,&quot;valid_design&quot;:&quot;abu-abu muda kesan beton\/putih&quot;,&quot;activitystartdate&quot;:null,&quot;activityenddate&quot;:null,&quot;id&quot;:70452630,&quot;almcod&quot;:null,&quot;name&quot;:&quot;NYBODA&quot;,&quot;type&quot;:&quot;ART&quot;,&quot;productarea&quot;:121,&quot;requires_assembly&quot;:true,&quot;default_image&quot;:&quot;https:\/\/d2xjmi1k71iy2m.cloudfront.net\/dairyfarm\/id\/images\/665\/0766513_PE753809_S3.jpg&quot;,&quot;designers&quot;:&quot;Ehl\u00e9n Johansson&quot;,&quot;stylegroup&quot;:&quot;IKEA Basic Modern&quot;,&quot;efficiency&quot;:null,&quot;price_range&quot;:&quot;Low&quot;,&quot;facts&quot;:&quot;meja tamu dg daun meja dpt dibalik&quot;,&quot;extra_facts&quot;:&quot;meja tamu dg daun meja dpt dibalik, abu-abu muda kesan beton\/putih&quot;,&quot;energy_tag&quot;:null,&quot;color&quot;:&quot;abu-abu muda-putih&quot;,&quot;size&quot;:null,&quot;search_value&quot;:&quot;'100':111C '70452630':4B 'abu':13,14 'abu-abu':12 'anda':25,37,52 'atas':96C,103C 'atau':30 'baja':98C 'banyak':90 'bawah':94C 'bentuk':70 'berbeda':36 'berdampingan':57 'bersama':32 'bersama-sama':31 'bersih':82 'besar':64 'dalam':19,34 'dan':50,69,79,83 'dapat':26,38,47,53 'daun':8A,41 'dengan':67,89 'dg':7A 'dibalik':11A,48 'didaur':112C 'didesain':22 'dikombinasikan':88 'dilapisi':99C 'dipindah':74 'dpt':10A 'dua':55 'epoksi':101C 'fibreboard':114C 'fleksibel':23 'foil':116C 'garis':81 'gaya':91 'h4':97C,104C 'hitam':49 'karena':45,77 'kebutuhan':44 'kemana':75 'kertas':107C,115C 'kombinasi':35 'krem':51 'lebah':110C 'lebih':63 'meja':1C,5A,9A,18,42,56,61,72,86 'meletakkan':54 'membuat':85 'memilih':39 'mendapat':59 'menggunakannya':27 'muda':16 'muda-putih':15 'mudah':73,87 'nyboda':3B,21 'particleboard':105C 'pengisian':106C 'perabot':92 'permukaan':60 'plastik':118C 'poliester':102C 'putih':17 'rangka':93C,95C 'ringan':78 'saja':76 'sama':33 'sarang':109C 'secara':28 'sederhana':84 'sehingga':24 'serbuk':100C 'seri':20 'sesuai':43,66 'sisinya':46 'sofa':2C,71 'stabil':80 'struktur':108C 'tamu':6A 'tepi':117C 'terpisah':29 'ukuran':68 'ulang':113C 'untuk':58 'warna':40 'yang':62,65&quot;,&quot;length_metric&quot;:null,&quot;length_imperial&quot;:null,&quot;width_metric&quot;:&quot;60&quot;,&quot;width_imperial&quot;:&quot;23 5\/8 inci&quot;,&quot;height_metric&quot;:&quot;50&quot;,&quot;height_imperial&quot;:&quot;19 5\/8 inci&quot;,&quot;diameter_metric&quot;:null,&quot;diameter_imperial&quot;:null,&quot;resume_measure_metric&quot;:&quot;75x60x50 cm&quot;,&quot;resume_measure_imperial&quot;:&quot;29 1\/2x23 5\/8x19 5\/8 inci&quot;,&quot;current_price&quot;:&quot;899000&quot;,&quot;hbp_price&quot;:null,&quot;original_price&quot;:&quot;899000&quot;,&quot;offer_price&quot;:null,&quot;family_price&quot;:null,&quot;stock&quot;:2,&quot;bti&quot;:false,&quot;is_new&quot;:true,&quot;top_seller&quot;:null,&quot;sold&quot;:0,&quot;show_in_web&quot;:true,&quot;buy_in_web&quot;:true,&quot;start_sale_date&quot;:&quot;2020-02-01&quot;,&quot;end_sale_date&quot;:null,&quot;start_sale_date_showable&quot;:&quot;2020-01-08&quot;,&quot;end_sale_date_showable&quot;:null,&quot;location&quot;:&quot;PICKING&quot;,&quot;salesmethod&quot;:&quot;F&quot;,&quot;formated_location&quot;:{&quot;title&quot;:null,&quot;result&quot;:&quot;&lt;span&gt;Available online and Order from I-Counter&lt;\/span&gt;&quot;},&quot;full_category&quot;:&quot;Furniture\/Hospitality \/Furniture\/Sofa tables&quot;,&quot;url&quot;:&quot;\/in\/produk\/ruang-keluarga\/meja-ruang-tamu\/meja-tamu-dan-meja-samping\/nyboda-meja-tamu-dg-daun-meja-dpt-dibalik-abu-abu-muda-putih-art-70452630&quot;},id,{&quot;position&quot;:1,&quot;currency&quot;:&quot;Rp&quot;,&quot;dec_num ...
# <span class="checkmark"></span>
# <span class="compareText">Bandingkan</span>
# </label>
# </div>
# </div>
# </div>
# <div class="card px-4" id="card_40369604">
# <div class="card-header">
# <a href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/nordviken-meja-dengan-daun-meja-lipat-hitam-art-40369604">
# <div class="itemBadges">
# </div>
# <span class="productImg">
# <img alt="NORDVIKEN - Meja dengan daun meja lipat, hitam" class="card-img-top" onerror="this.src='/webroot/img/icons/noImage.png?v=1579530442'" src="https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/142/0714209_PE729967_S3.jpg"/>
# </span>
# </a>
# </div>
# <div class="card-body">
# <div class="itemInfo">
# <input name="productInfo" type="hidden" value='{"name":"NORDVIKEN - Meja dengan daun meja lipat, hitam","brand":"NORDVIKEN","id":"40369604","price":"2499000","category":"Furniture\/Dining\/Dining tables\/Tables ","variant":"ART"}'/>
# <a class="itemName" href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/nordviken-meja-dengan-daun-meja-lipat-hitam-art-40369604">
# <h6 class="display-7">NORDVIKEN</h6>
# </a>
# <div class="itemDetails">
# <span class="itemFacts">Meja dengan daun meja lipat, hitam</span>
# </div>
# <div class="itemPriceBox">
# <div class="itemPrice-wrapper">
# <p class="itemNormalPrice display-6">
# <span data-price="2499000">Rp 2.499.000</span>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="card-footer">
# <button class="btn btn-outline-gray-medium mx-auto btn-icon sidenavItem quickLook" data-action="sidenav" data-item="40369604" data-stock="8">
# <span class="icon-quickview"></span>
# <span>Lihat sekilas</span>
# </button>
# </div>
# <div class="card-compare">
# <div class="ml-4 check">
# <label class="checkboxCompare" for="check_40369604">
# <input class="listItem" id="check_40369604" onchange="Comparator.addItemComparator({&quot;combination_items&quot;:null,&quot;partnumber&quot;:&quot;40369604&quot;,&quot;has_relations&quot;:false,&quot;unit_value&quot;:null,&quot;unit_imperial&quot;:null,&quot;unit_metric&quot;:null,&quot;unit_unit&quot;:null,&quot;valid_design&quot;:&quot;hitam&quot;,&quot;activitystartdate&quot;:null,&quot;activityenddate&quot;:null,&quot;id&quot;:40369604,&quot;almcod&quot;:null,&quot;name&quot;:&quot;NORDVIKEN&quot;,&quot;type&quot;:&quot;ART&quot;,&quot;productarea&quot;:811,&quot;requires_assembly&quot;:true,&quot;default_image&quot;:&quot;https:\/\/d2xjmi1k71iy2m.cloudfront.net\/dairyfarm\/id\/images\/142\/0714209_PE729967_S3.jpg&quot;,&quot;designers&quot;:&quot;Francis Cayouette&quot;,&quot;stylegroup&quot;:&quot;IKEA Basic Traditional&quot;,&quot;efficiency&quot;:null,&quot;price_range&quot;:&quot;Medium&quot;,&quot;facts&quot;:&quot;meja dengan daun meja lipat&quot;,&quot;extra_facts&quot;:&quot;meja dengan daun meja lipat, hitam&quot;,&quot;energy_tag&quot;:null,&quot;color&quot;:&quot;hitam&quot;,&quot;size&quot;:null,&quot;search_value&quot;:&quot;'-4':44 '2':43 '40369604':3B 'akrilik':67C,82C,98C,106C,118C 'anda':32 'ash':64C,76C,79C,92C,95C,103C,115C 'bawah':56C 'bening':68C,83C,99C,107C,119C 'bertahun':35 'bertahun-tahun':34 'berwarna':69C,84C,100C,108C,120C 'birch':124C 'dalam':18 'dan':22 'dapat':41 'daun':6A,39,70C,86C 'daya':20 'dengan':5A,14,38,53 'di':30 'diuji':13 'h4':57C,72C,88C,110C,122C 'hari':29 'hitam':9 'ini':11 'kaki':109C 'kami':17 'kayu':58C,63C,75C,78C,91C,94C,102C,114C,123C 'keamanan':23 'kebutuhan':54 'kertas':85C 'ketat':16 'lacquer':66C,81C,97C,105C,117C 'lipat':8A 'meja':1C,4A,7A,10,37,40,71C 'memungkinkan':47 'menahan':25 'menampung':42 'menyesuaikan':49 'nordviken':2B 'orang':45 'particleboard':73C,89C,111C 'penggunaan':26 'perekat':61C,112C 'perpanjangan':87C 'pewarna':65C,80C,96C,104C,116C 'pinus':59C 'rangka':55C 'rel':121C 'rumah':31 'sehari':28 'sehari-hari':27 'sehingga':46 'selama':33 'sesuai':52 'solid':60C,125C 'stabilitas':19 'standar':15 'tabel':51 'tahan':21 'tahun':36 'telah':12 'ukuran':50 'untuk':24,48 'veneer':62C,74C,77C,90C,93C,101C,113C&quot;,&quot;length_metric&quot;:null,&quot;length_imperial&quot;:null,&quot;width_metric&quot;:&quot;74&quot;,&quot;width_imperial&quot;:&quot;29 1\/8 inci&quot;,&quot;height_metric&quot;:&quot;75&quot;,&quot;height_imperial&quot;:&quot;29 1\/2 inci&quot;,&quot;diameter_metric&quot;:null,&quot;diameter_imperial&quot;:null,&quot;resume_measure_metric&quot;:&quot;74\/104x74 cm&quot;,&quot;resume_measure_imperial&quot;:&quot;29 1\/8\/41x29 1\/8 inci&quot;,&quot;current_price&quot;:&quot;2499000&quot;,&quot;hbp_price&quot;:null,&quot;original_price&quot;:&quot;2499000&quot;,&quot;offer_price&quot;:null,&quot;family_price&quot;:null,&quot;stock&quot;:8,&quot;bti&quot;:false,&quot;is_new&quot;:false,&quot;top_seller&quot;:null,&quot;sold&quot;:0,&quot;show_in_web&quot;:true,&quot;buy_in_web&quot;:true,&quot;start_sale_date&quot;:&quot;2019-08-01&quot;,&quot;end_sale_date&quot;:null,&quot;start_sale_date_showable&quot;:null,&quot;end_sale_date_showable&quot;:null,&quot;location&quot;:&quot;PICKING&quot;,&quot;salesmethod&quot;:&quot;F&quot;,&quot;formated_location&quot;:{&quot;title&quot;:null,&quot;result&quot;:&quot;&lt;span&gt;Available online and Order from I-Counter&lt;\/span&gt;&quot;},&quot;full_category&quot;:&quot;Furniture\/Dining\/Dining tables\/Tables &quot;,&quot;url&quot;:&quot;\/in\/produk\/ruang-makan\/meja-ruang-makan\/meja-makan\/nordviken-meja-dengan-daun-meja-lipat-hitam-art-40369604&quot;},id,{&quot;position&quot;:1,&quot;currency&quot;:&quot;Rp&quot;,&quot;dec_number&quot;:2,&quot;dec_separator&quot;:&quot;,&quot;,&quot;thousand_separator&quot;:&quot;.&quot;})" type="checkbox" value=""/>
# <span class="checkmark"></span>
# <span class="compareText">Bandingkan</span>
# </label>
# </div>
# </div>
# </div>
# <div class="card px-4" id="card_79251175">
# <div class="card-header">
# <a href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/ingatorp-ingolf-meja-dan-4-kursi-hitam-cokelat-hitam-spr-79251175">
# <div class="itemBadges">
# </div>
# <span class="productImg">
# <img alt="INGATORP/INGOLF - Meja dan 4 kursi, hitam/cokelat-hitam" class="card-img-top" onerror="this.src='/webroot/img/icons/noImage.png?v=1579530442'" src="https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/452/0445212_PE595673_S3.jpg"/>
# </span>
# </a>
# </div>
# <div class="card-body">
# <div class="itemInfo">
# <input name="productInfo" type="hidden" value='{"name":"INGATORP\/INGOLF - Meja dan 4 kursi, hitam\/cokelat-hitam","brand":"INGATORP\/INGOLF","id":"79251175","price":"9579000","category":"Furniture\/Dining\/Dining tables\/Tables ","variant":"SPR"}'/>
# <a class="itemName" href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/ingatorp-ingolf-meja-dan-4-kursi-hitam-cokelat-hitam-spr-79251175">
# <h6 class="display-7">INGATORP/INGOLF</h6>
# </a>
# <div class="itemDetails">
# <span class="itemFacts">Meja dan 4 kursi, hitam/cokelat-hitam</span>
# </div>
# <div class="itemPriceBox">
# <div class="itemPrice-wrapper">
# <p class="itemNormalPrice display-6">
# <span data-price="9579000">Rp 9.579.000</span>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="card-footer">
# <button class="btn btn-outline-gray-medium mx-auto btn-icon sidenavItem quickLook" data-action="sidenav" data-item="79251175" data-stock="3">
# <span class="icon-quickview"></span>
# <span>Lihat sekilas</span>
# </button>
# </div>
# <div class="card-compare">
# <div class="ml-4 check">
# <label class="checkboxCompare" for="check_79251175">
# ...
# <span class="icon-quickview"></span>
# <span>Lihat sekilas</span>
# </button>
# </div>
# <div class="card-compare">
# <div class="ml-4 check">
# <label class="checkboxCompare" for="check_69221301">
# <input class="listItem" id="check_69221301" onchange="Comparator.addItemComparator({&quot;combination_items&quot;:null,&quot;partnumber&quot;:&quot;69221301&quot;,&quot;has_relations&quot;:true,&quot;unit_value&quot;:null,&quot;unit_imperial&quot;:null,&quot;unit_metric&quot;:null,&quot;unit_unit&quot;:null,&quot;valid_design&quot;:&quot;cokelat tua\/biru&quot;,&quot;activitystartdate&quot;:null,&quot;activityenddate&quot;:null,&quot;id&quot;:69221301,&quot;almcod&quot;:null,&quot;name&quot;:&quot;ODGER\/EKEDALEN&quot;,&quot;type&quot;:&quot;SPR&quot;,&quot;productarea&quot;:811,&quot;requires_assembly&quot;:true,&quot;default_image&quot;:&quot;https:\/\/d2xjmi1k71iy2m.cloudfront.net\/dairyfarm\/id\/images\/377\/0737723_PE741236_S3.jpg&quot;,&quot;designers&quot;:&quot;Ehl\u00e9n Johansson\/J L\u00f6fgren\/J Pettersson&quot;,&quot;stylegroup&quot;:null,&quot;efficiency&quot;:null,&quot;price_range&quot;:null,&quot;facts&quot;:&quot;meja dan 4 kursi&quot;,&quot;extra_facts&quot;:&quot;meja dan 4 kursi, cokelat tua\/biru&quot;,&quot;energy_tag&quot;:null,&quot;color&quot;:&quot;biru-cokelat tua&quot;,&quot;size&quot;:null,&quot;search_value&quot;:&quot;'4':7A '69221301':4B 'adanya':29 'akrilik':101C,115C,134C 'anda':23 'ash':98C,112C,118C,131C 'atas':90 'bagian':89 'bahkan':51 'bangku':77 'banyak':58 'bawah':63,88,121C 'bening':102C,116C,135C 'benturan':35 'berada':47 'berwarna':103C 'birch':124C 'biru':10 'biru-cokelat':9 'cokelat':11 'composite':145C 'dan':6A,36,41,76 'dapat':65,85 'dari':34,78 'daun':17,82,104C,106C 'dengan':28,66,74 'desain':13 'di':48,62,87 'dikombinasikan':73 'dipanjangkan':55,68 'disimpan':86 'duduk':138C 'ekedalen':3B 'gagang':141C 'goresan':37 'h4':93C,108C,122C,142C,147C 'kaki':44,92C,140C,146C 'karet':148C 'kayu':94C,97C,111C,117C,123C,126C,130C 'kerangka':136C 'ketika':22,52 'kursi':8A,61,75 'lacquer':100C,114C,133C 'lama':43 'lapis':95C 'lipatan':21 'meja':1C,5A,18,25,38,45,50,53,64,83,91,105C 'melindungi':33 'memanjangkannya':27 'membuat':16 'menggunakan':24 'menjadi':39 'mudah':67,72 'odger':2B 'oleh':69 'orang':71 'particleboard':109C 'perawatan':30 'permukaan':31 'perpanjangan':107C 'pewarna':99C,113C,132C 'pintar':14 'pinus':127C 'plastic':144C 'rangka':120C,139C 'ruang':59 'sama':81 'satu':70 'sedang':54 'sehingga':56 'selalu':46 'seri':79 'sintetis':149C 'solid':119C,125C,128C 'stabil':40 'sudut':49 'tahan':42 'tambahan':84 'tanpa':26 'tempat':137C 'terlihat':20 'tersedia':57 'tidak':19 'tua':12 'untuk':60 'veneer':96C,110C,129C 'wood':143C 'yang':15,32,80&quot;,&quot;length_metric&quot;:null,&quot;length_imperial&quot;:null,&quot;width_metric&quot;:null,&quot;width_imperial&quot;:null,&quot;height_metric&quot;:null,&quot;height_imperial&quot;:null,&quot;diameter_metric&quot;:null,&quot;diameter_imperial&quot;:null,&quot;resume_measure_metric&quot;:&quot;120\/180 cm&quot;,&quot;resume_measure_imperial&quot;:&quot;47 1\/4\/70 7\/8 inci&quot;,&quot;current_price&quot;:&quot;9179000&quot;,&quot;hbp_price&quot;:&quot;9179000&quot;,&quot;original_price&quot;:&quot;9179000&quot;,&quot;offer_price&quot;:&quot;9179000&quot;,&quot;family_price&quot;:null,&quot;stock&quot;:2,&quot;bti&quot;:false,&quot;is_new&quot;:false,&quot;top_seller&quot;:null,&quot;sold&quot;:null,&quot;show_in_web&quot;:true,&quot;buy_in_web&quot;:true,&quot;start_sale_date&quot;:&quot;2017-10-01&quot;,&quot;end_sale_date&quot;:&quot;2020-08-01&quot;,&quot;start_sale_date_showable&quot;:null,&quot;end_sale_date_showable&quot;:null,&quot;location&quot;:null,&quot;salesmethod&quot;:&quot;SPR&quot;,&quot;formated_location&quot;:null,&quot;full_category&quot;:&quot;Furniture\/Dining\/Dining tables\/Tables &quot;,&quot;url&quot;:&quot;\/in\/produk\/ruang-makan\/meja-ruang-makan\/meja-makan\/odger-ekedalen-meja-dan-4-kursi-biru-cokelat-tua-spr-69221301&quot;},id,{&quot;position&quot;:1,&quot;currency&quot;:&quot;Rp&quot;,&quot;dec_number&quot;:2,&quot;dec_separator&quot;:&quot;,&quot;,&quot;thousand_separator&quot;:&quot;.&quot;})" ty ...
# <span class="checkmark"></span>
# <span class="compareText">Bandingkan</span>
# </label>
# </div>
# </div>
# </div>
# <div class="card px-4" id="card_39297260">
# <div class="card-header">
# <a href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/ekedalen-tossberg-meja-dan-4-kursi-abu-abu-cokelat-tua-spr-39297260">
# <div class="itemBadges">
# </div>
# <span class="productImg">
# <img alt="EKEDALEN/TOSSBERG - Meja dan 4 kursi, cokelat tua logam/abu-abu" class="card-img-top" onerror="this.src='/webroot/img/icons/noImage.png?v=1579530442'" src="https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/618/0661879_PE711651_S3.jpg"/>
# </span>
# </a>
# </div>
# <div class="card-body">
# <div class="itemInfo">
# <input name="productInfo" type="hidden" value='{"name":"EKEDALEN\/TOSSBERG - Meja dan 4 kursi, cokelat tua logam\/abu-abu","brand":"EKEDALEN\/TOSSBERG","id":"39297260","price":"19979000","category":"Furniture\/Dining\/Dining tables\/Tables ","variant":"SPR"}'/>
# <a class="itemName" href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/ekedalen-tossberg-meja-dan-4-kursi-abu-abu-cokelat-tua-spr-39297260">
# <h6 class="display-7">EKEDALEN/TOSSBERG</h6>
# </a>
# <div class="itemDetails">
# <span class="itemFacts">Meja dan 4 kursi, cokelat tua logam/abu-abu</span>
# </div>
# <div class="itemPriceBox">
# <div class="itemPrice-wrapper">
# <p class="itemNormalPrice display-6">
# <span data-price="19979000">Rp 19.979.000</span>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="card-footer">
# <button class="btn btn-outline-gray-medium mx-auto btn-icon sidenavItem quickLook" data-action="sidenav" data-item="39297260" data-stock="3">
# <span class="icon-quickview"></span>
# <span>Lihat sekilas</span>
# </button>
# </div>
# <div class="card-compare">
# <div class="ml-4 check">
# <label class="checkboxCompare" for="check_39297260">
# <input class="listItem" id="check_39297260" onchange="Comparator.addItemComparator({&quot;combination_items&quot;:null,&quot;partnumber&quot;:&quot;39297260&quot;,&quot;has_relations&quot;:false,&quot;unit_value&quot;:null,&quot;unit_imperial&quot;:null,&quot;unit_metric&quot;:null,&quot;unit_unit&quot;:null,&quot;valid_design&quot;:&quot;cokelat tua logam\/abu-abu&quot;,&quot;activitystartdate&quot;:null,&quot;activityenddate&quot;:null,&quot;id&quot;:39297260,&quot;almcod&quot;:null,&quot;name&quot;:&quot;EKEDALEN\/TOSSBERG&quot;,&quot;type&quot;:&quot;SPR&quot;,&quot;productarea&quot;:811,&quot;requires_assembly&quot;:true,&quot;default_image&quot;:&quot;https:\/\/d2xjmi1k71iy2m.cloudfront.net\/dairyfarm\/id\/images\/618\/0661879_PE711651_S3.jpg&quot;,&quot;designers&quot;:&quot;Ehl\u00e9n Johansson\/IKEA of Sweden&quot;,&quot;stylegroup&quot;:null,&quot;efficiency&quot;:null,&quot;price_range&quot;:null,&quot;facts&quot;:&quot;meja dan 4 kursi&quot;,&quot;extra_facts&quot;:&quot;meja dan 4 kursi, cokelat tua logam\/abu-abu&quot;,&quot;energy_tag&quot;:null,&quot;color&quot;:&quot;abu-abu-cokelat tua&quot;,&quot;size&quot;:null,&quot;search_value&quot;:&quot;'100':188C '39297260':4B '4':7A '60':147C,171C 'abu':10,11 'abu-abu-cokelat':9 'adanya':22 'akrilik':107C,120C,134C 'anda':47 'asetal':178C 'ash':104C,117C,123C,131C 'atas':91 'bagian':90 'bahkan':59 'baja':139C,140C,176C 'bangku':78 'bantalan':159C 'banyak':66 'bawah':71,89,94C 'bening':108C,121C,135C 'benturan':28 'berada':55 'berpigmen':185C 'berwarna':136C 'birch':97C 'busa':141C,145C,165C,169C 'cokelat':12 'dan':6A,29,34,77 'dapat':14,86 'dari':27,79 'daun':41,83,109C,111C 'dengan':15,21,75 'desain':37 'di':56,70,88 'dikombinasikan':74 'dingin':146C,170C 'dipanjangkan':17,63 'disimpan':87 'ditenun':154C,157C 'duduk':161C 'ekedalen':2B 'elastis':143C,167C 'epoksi':184C 'fibreboard':158C 'goresan':30 'h4':95C,113C,126C,138C,162C,175C,187C 'isi':150C,163C 'kaki':52,125C,174C 'kayu':96C,99C,103C,116C,122C,127C,130C 'ketika':46,60 'kg':148C,172C 'kursi':8A,69,76 'lacquer':106C,119C,133C 'lama':36 'lapis':128C 'lapisan':181C 'lipatan':45 'm3':149C,173C 'meja':1C,5A,31,42,49,53,58,61,72,84,92,110C 'melindungi':26 'memanjangkannya':51 'membuat':40 'menggunakan':48 'menjadi':32 'mudah':16,73 'oleh':18 'orang':20 'particleboard':114C 'perawatan':23 'permukaan':24 'perpanjangan':112C 'pewarna':105C,118C,132C 'pintar':38 'pinus':100C 'plastik':177C,179C 'poliamida':180C 'poliester':151C,164C,183C,189C 'polipropilena':152C,155C 'poliuretana':142C,166C 'rangka':93C,137C 'ruang':67 'sama':82 'satu':19 'sedang':62 'sehingga':64 'selalu':54 'serbuk':182C 'seri':80 'solid':98C,101C,124C 'stabil':33 'sudut':57 'tahan':35 'tambahan':85 'tanpa':50 'tekstil':186C 'tempat':160C 'terlihat':44 'tersedia':65 'tidak':43,153C,156C 'tinggi':144C,168C 'tossberg':3B 'tua':13 'untuk':68 'veneer':102C,115C,129C 'yang':25,39,81&quot;,&quot;length_metric&quot;:null,&quot;length_imperial&quot;:null,&quot;width_metric&quot;:null,&quot;width_imperial&quot;:null,&quot;height_metric&quot;:null,&quot;height_imperial&quot;:null,&quot;diameter_metric&quot;:null,&quot;diameter_imperial&quot;:null,&quot;resume_measure_metric&quot;:&quot;120\/180 cm&quot;,&quot;resume_measure_imperial&quot;:&quot;47 1\/4\/70 7\/8 inci&quot;,&quot;current_price&quot;:&quot;19979000&quot;,&quot;hbp_price&quot;:&quot;19979000&quot;,&quot;original_price&quot;:&quot;19979000&quot;,&quot;offer_price&quot;:&quot;19979000&quot;,&quot;family_price&quot;:null,&quot;stock&quot;:3,&quot;bti&quot;:false,&quot;is_new&quot;:false,&quot;top_seller&quot;:null,&quot;sold&quot;:null,&quot;show_in_web&quot;:true,&quot;buy_in_web&quot;:true,&quot;start_sale_date&quot;:&quot;2019-04-01&quot;,&quot;end_sale_date&quot;:null,&quot;start_sale_date_showable&quot;:null,&quot;end_sale_date_showable&quot;:null,&quot;location&quot;:null,&quot;salesmethod&quot;:&quot;SPR&quot;,&quot;formated_location&quot;:null,&quot;full_category&quot;:&quot;Furniture\/Dini ...
# <span class="checkmark"></span>
# <span class="compareText">Bandingkan</span>
# </label>
# </div>
# </div>
# </div>
# <div class="card px-4" id="card_99280681">
# <div class="card-header">
# <a href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/ingatorp-ingolf-meja-dan-6-kursi-abu-abu-krem-hitam-spr-99280681">
# <div class="itemBadges">
# </div>
# <span class="productImg">
# <img alt="INGATORP/INGOLF - Meja dan 6 kursi, hitam/Nolhaga abu-abu/krem" class="card-img-top" onerror="this.src='/webroot/img/icons/noImage.png?v=1579530442'" src="https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/343/0634335_PE696401_S3.jpg"/>
# </span>
# </a>
# </div>
# <div class="card-body">
# <div class="itemInfo">
# <input name="productInfo" type="hidden" value='{"name":"INGATORP\/INGOLF - Meja dan 6 kursi, hitam\/Nolhaga abu-abu\/krem","brand":"INGATORP\/INGOLF","id":"99280681","price":"13169000","category":"Furniture\/Dining\/Dining tables\/Tables ","variant":"SPR"}'/>
# <a class="itemName" href="/in/produk/ruang-makan/meja-ruang-makan/meja-makan/ingatorp-ingolf-meja-dan-6-kursi-abu-abu-krem-hitam-spr-99280681">
# <h6 class="display-7">INGATORP/INGOLF</h6>
# </a>
# <div class="itemDetails">
# <span class="itemFacts">Meja dan 6 kursi, hitam/Nolhaga abu-abu/krem</span>
# </div>
# <div class="itemPriceBox">
# <div class="itemPrice-wrapper">
# <p class="itemNormalPrice display-6">
# <span data-price="13169000">Rp 13.169.000</span>
# </p>
# </div>
# </div>
# </div>
# <p class="itemMore mt-2 pb-1">Tersedia lebih banyak pilihan</p>
# </div>
# <div class="card-footer">
# <button class="btn btn-outline-gray-medium mx-auto btn-icon sidenavItem quickLook" data-action="sidenav" data-item="99280681" data-stock="3">
# <span class="icon-quickview"></span>
# <span>Lihat sekilas</span>
# </button>
# </div>
# <div class="card-compare">
# <div class="ml-4 check">
# <label class="checkboxCompare" for="check_99280681">
# <input class="listItem" id="check_99280681" onchange="Comparator.addItemComparator({&quot;combination_items&quot;:null,&quot;partnumber&quot;:&quot;99280681&quot;,&quot;has_relations&quot;:true,&quot;unit_value&quot;:null,&quot;unit_imperial&quot;:null,&quot;unit_metric&quot;:null,&quot;unit_unit&quot;:null,&quot;valid_design&quot;:&quot;hitam\/Nolhaga abu-abu\/krem&quot;,&quot;activitystartdate&quot;:null,&quot;activityenddate&quot;:null,&quot;id&quot;:99280681,&quot;almcod&quot;:null,&quot;name&quot;:&quot;INGATORP\/INGOLF&quot;,&quot;type&quot;:&quot;SPR&quot;,&quot;productarea&quot;:811,&quot;requires_assembly&quot;:true,&quot;default_image&quot;:&quot;https:\/\/d2xjmi1k71iy2m.cloudfront.net\/dairyfarm\/id\/images\/343\/0634335_PE696401_S3.jpg&quot;,&quot;designers&quot;:&quot;Carina Bengs\/Ebba Strandmark&quot;,&quot;stylegroup&quot;:null,&quot;efficiency&quot;:null,&quot;price_range&quot;:null,&quot;facts&quot;:&quot;meja dan 6 kursi&quot;,&quot;extra_facts&quot;:&quot;meja dan 6 kursi, hitam\/Nolhaga abu-abu\/krem&quot;,&quot;energy_tag&quot;:null,&quot;color&quot;:&quot;abu-abu\/krem-hitam&quot;,&quot;size&quot;:null,&quot;search_value&quot;:&quot;'-6':33 '1':15,27 '25':211C '35':189C,198C '4':32 '6':7A '75':209C '99280681':4B 'abs':130C 'abu':10,11 'abu-abu':9 'acara':65 'akrilik':124C,133C,146C,158C,166C,178C,218C 'ash':137C,150C 'bagian':151C 'bawah':91 'bening':134C,147C,159C,219C 'bentuk':103 'berbentuk':172C,176C 'berlengan':75 'birch':121C,155C,163C 'busa':183C,187C,192C,196C 'cat':123C,165C,177C 'cocok':63 'dan':6A,72,82,110 'dapat':24,88,94 'daun':16,28,50,125C,138C 'dengan':26,79,106 'di':54 'dibersihkan':62 'didorong':89 'diduduki':78 'digunakan':99 'diletakkan':53 'dingin':188C,197C 'dipanjangkan':48 'diperpanjang':25 'ditenun':205C 'divernis':59 'duduk':180C 'dudukan':83 'ekstra':85 'elastis':185C,194C 'fibreboard':182C 'h4':119C,127C,140C,153C,161C,168C,181C,208C 'hitam':14 'ingatorp':2B,109 'ingolf':3B 'isi':201C 'jernih':60 'kaki':107,116C 'karena':49,70 'katun':210C 'kayu':120C,136C,149C,154C,162C,213C 'ke':90 'kebutuhan':41 'ketinggian':73 'kg':190C,199C 'krem':13 'krem-hitam':12 'kursi':8A,74,87,112 'lacquer':132C,145C,157C,217C 'lainnya':152C 'lama':69 'lapisan':169C,173C 'm3':191C,200C 'makan':22,66 'malam':67 'meja':1C,5A,17,21,29,39,46,51,56,92,108,126C 'memberikan':111 'memiliki':102 'memungkinkan':35 'menghemat':95 'menyesuaikan':37 'modern':113 'mudah':61 'nyaman':76 'orang':34 'panjang':71 'papan':170C,174C 'particleboard':128C,141C 'penyambung':52 'permukaan':57 'perpanjangan':139C 'pewarna':131C,144C,216C 'pinus':214C 'plastik':129C,143C 'poliester':202C,212C 'polipropilena':203C 'poliuretana':184C,193C 'punggung':81 'punggungnya':101 'rangka':160C 'rel':117C 'ruang':96 'saat':45,97 'sama':105 'sambungan':44 'samping':118C 'sandaran':80,100,167C 'sarung':206C,207C 'sehingga':93 'sentuhan':114 'serat':171C,175C 'sesuai':40 'solid':122C,156C,164C,215C 'sudah':19 'tambahan':18,30 'tebal':86 'tempat':179C 'tepi':142C 'terdapat':43 'termasuk':20 'tidak':42,47,98,204C 'tinggi':186C,195C 'tradisional':115 'ujung':55 'ukuran':38 'untuk':31,36,64,77 'veneer':135C,148C 'yang':23,58,68,84,104&quot;,&quot;length_metric&quot;:null,&quot;length_imperial&quot;:null,&quot;width_metric&quot;:&quot;87&quot;,&quot;width_imperial&quot;:&quot;34 1\/4 inci&quot;,&quot;height_metric&quot;:&quot;74&quot;,&quot;height_imperial&quot;:&quot;29 1\/8 inci&quot;,&quot;diameter_metric&quot;:null,&quot;diameter_imperial&quot;:null,&quot;resume_measure_metric&quot;:&quot;155\/215 cm&quot;,&quot;resume_measure_imperial&quot;:&quot;61\/84 5\/8 inci&quot;,&quot;current_price&quot;:&quot;13169000&quot;,&quot;hbp_price&quot;:&quot;13169000&quot;,&quot;original_price&quot;:&quot;13169000&quot;,&quot;offer_price&quot;:&quot;13169000&quot;,&quot;family_price&quot;:null,&quot;stock&quot;:3,&quot;bti&quot;:false,&quot;is_new&quot;:false,&quot;top_seller&quot;:null,&quot;sold&quot;:null,&quot;show_in_web&quot;:true,&quot;buy_in_web&q ...
# <span class="checkmark"></span>
# <span class="compareText">Bandingkan</span>
# </label>
# </div>
# </div>
# </div>

# %%
#variabel dataImg mencari data dengan tag img dan class nya
#dan menampilkan dataImg nya berupa src yaitu link gambarnya
content = driver.page_source
soup = BeautifulSoup(content)
for link in soup.find_all('div', class_="card px-4"):
    dataImg = link.find('img', class_="card-img-top")
    print(dataImg['src'])
# Out:
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/689/0368937_PE549760_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/665/0766504_PE753800_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/665/0766507_PE753803_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/377/0737793_PE741254_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/492/0449209_PE598742_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/665/0766508_PE753804_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/665/0766513_PE753809_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/142/0714209_PE729967_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/452/0445212_PE595673_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/497/0149768_PE307925_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/386/0138625_PE298367_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/174/0517427_PE640682_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/174/0517431_PE640686_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/447/0744786_PE743398_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/369/0736912_PE740802_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/357/0735754_PE740162_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/174/0517418_PE640674_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/167/0516748_PE640525_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/171/0517141_PE640625_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/167/0516714_PE640511_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/173/0517391_PE640664_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/174/0517423_PE640678_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/174/0517419_PE640676_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/198/0519886_PE641846_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/377/0737713_PE741228_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/377/0737709_PE741230_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/376/0737690_PE741210_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/376/0737688_PE741208_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/379/0737941_PE741273_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/377/0737712_PE741227_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/198/0519882_PE641842_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/376/0737670_PE741200_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/199/0519904_PE641863_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/199/0519936_PE641881_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/377/0737792_PE741258_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/379/0737940_PE741266_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/377/0737791_PE741257_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/377/0737723_PE741236_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/618/0661879_PE711651_S3.jpg
# https://d2xjmi1k71iy2m.cloudfront.net/dairyfarm/id/images/343/0634335_PE696401_S3.jpg

# %%
content = driver.page_source
soup = BeautifulSoup(content)
for link in soup.find_all('div', class_="card px-4"):
    dataImg = link.find('img', class_="card-img-top")
    
    name=link.find('span', class_="itemFacts")
    print(name.get_text())
# Out:
# Meja dengan daun meja lipat, hitam
# Meja tamu dg daun meja dpt dibalik, abu-abu tua kesan beton/hitam
# Meja tamu dg daun meja dpt dibalik, abu-abu muda kesan beton/putih
# Meja dan 4 kursi, hitam
# Meja dengan daun meja lipat, putih
# Meja tamu dg daun meja dpt dibalik, abu-abu tua kesan beton/hitam
# Meja tamu dg daun meja dpt dibalik, abu-abu muda kesan beton/putih
# Meja dengan daun meja lipat, hitam
# Meja dan 4 kursi, hitam/cokelat-hitam
# Meja dengan daun meja lipat, hitam-cokelat
# Meja dengan daun meja lipat, bambu/putih
# Meja yang dapat dipanjangkan, putih
# Meja yang dapat dipanjangkan, putih
# Meja dan 4 kursi, putih/merah merah
# Meja dengan daun meja lipat, putih
# Meja dg daun meja lipat, luar ruang, diwarnai cokelat
# Meja yang dapat dipanjangkan, putih
# Meja yang dapat dipanjangkan, putih
# Meja yang dapat dipanjangkan, kayu birch
# Meja yang dapat dipanjangkan, cokelat tua
# Meja yang dapat dipanjangkan, kayu oak
# Meja yang dapat dipanjangkan, kayu birch
# Meja dan 2 kursi, putih/Orrsta abu-abu muda
# Meja dan 2 kursi, kayu oak/Orrsta abu-abu muda
# Meja dan 2 kursi, kayu oak/putih krem
# Meja dan 2 kursi, kayu oak/putih
# Meja dan 2 kursi, cokelat tua/Orrsta abu-abu muda
# Meja dan 2 kursi, kayu birch/Orrsta abu-abu muda
# Meja dan 4 kursi, putih/Nordvalla krem
# Meja dan 2 kursi, cokelat tua/cokelat
# Meja dan 2 kursi, putih/cokelat
# Meja dan 2 kursi, putih/Mjuk emas-cokelat
# Meja dan 4 kursi, cokelat tua/putih
# Meja dan 4 kursi, putih/biru
# Meja dan 4 kursi, putih
# Meja dan 4 kursi, hitam/Nolhaga abu-abu/krem
# Meja dan 4 kursi, hitam
# Meja dan 4 kursi, cokelat tua/biru
# Meja dan 4 kursi, cokelat tua logam/abu-abu
# Meja dan 6 kursi, hitam/Nolhaga abu-abu/krem

# %%
content = driver.page_source
soup = BeautifulSoup(content)
for link in soup.find_all('div', class_="itemPriceBox"):
    dataImg = link.find('img', class_="card-img-top")
    
    name = link.find('span', class_="itemFacts")
    
    price = link.find('span')
    print(price.get_text())
# Out:
# Rp 1.999.000
# Rp 1.499.000
# Rp 1.499.000
# Rp 13.179.000
# Rp 2.999.000
# Rp 899.000
# Rp 899.000
# Rp 2.499.000
# Rp 9.579.000
# Rp 2.999.000
# Rp 3.999.000
# Rp 1.999.000
# Rp 1.499.000
# Rp 6.779.000
# Rp 899.000
# Rp 2.499.000
# Rp 2.999.000
# Rp 3.999.000
# Rp 2.999.000
# Rp 3.999.000
# Rp 2.999.000
# Rp 3.999.000
# Rp 4.789.000
# Rp 4.989.000
# Rp 5.589.000
# Rp 4.589.000
# Rp 4.789.000
# Rp 4.789.000
# Rp 13.379.000
# Rp 5.589.000
# Rp 5.589.000
# Rp 8.989.000
# Rp 7.179.000
# Rp 9.179.000
# Rp 15.179.000
# Rp 13.379.000
# Rp 15.179.000
# Rp 9.179.000
# Rp 19.979.000
# Rp 13.169.000

# %%
content = driver.page_source
soup = BeautifulSoup(content)
for link in soup.find_all('div', class_="card px-4"):
    dataImg = link.find('img', class_="card-img-top")
    
    name = link.find('span', class_="itemFacts")
    
    price = link.find('div', 'span', class_="itemPriceBox")
#variabel product, prices, image ini mendefinisikan data yang
#sudah didapatkan dan memasukan ke dalam bentuk array
#yang sudah dibuat sebelumnya
    product.append(name.get_text())
    prices.append(price.get_text())
    image.append(dataImg['src'])

# %%
#dari data diatas kemudian menyimpan nya ke dalam format .csv
df = pd.DataFrame({'Product':product, 'Price':prices, 'Image':image})
df.to_csv('ikea3.csv', index=False, encoding='utf-8')

# %%
#dari data diatas kemudian mentimpan nya ke dalam format .json
df = pd.DataFrame({'Product':product, 'Price':prices, 'Image':image})
df.to_json('ikea5.json', orient = "table")
